# %% [markdown]
# -------------------------
# #### Aim : try regression model on automobiles dataset
# - understand the ML and metrics
# - after removal of 'year' column
# - encode the `origin` column with OHE (one hot encoding)
# - the rows with horsepower= "?" are replace with the mean value of the horsepower column
# ---------------------------------
#
# **About the dataset**
# The data is technical spec of cars. The dataset is downloaded from UCI Machine Learning Repository https://www.kaggle.com/uciml/autompg-dataset
#
# (a) Origin: This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The dataset was used in the 1983 American Statistical Association Exposition.
#
# Attribute Information:
#
# |column name | type of column|
# |------------|---------------|
# |`mpg`: |continuous|
# |`cylinders`: |multi-valued discrete|
# |`displacement`: |continuous|
# |`horsepower`: |continuous|
# |`weight`: |continuous|
# |`acceleration`: |continuous|
# |model year: |multi-valued discrete|
# |origin: |multi-valued discrete|
# |car name: |string (unique for each instance)|
#
# Missing Attribute Values: horsepower has 6 missing values

# %%
import pandas as pd
import numpy as np

# import the ML algorithm
from sklearn.linear_model import LinearRegression

# %%
location = "https://github.com/gridflowai/gridflowAI-datasets-icons/raw/master/AI-DATASETS/01-MISC/auto-mpg.csv"

# %%
# load the training data from glass data set
df_training = pd.read_csv(location)
df_training
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
df_training.drop(['car name'], axis=1, inplace=True)

# %%
df_training
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin
# 0            70       1
# 1            70       1
# 2            70       1
# 3            70       1
# 4            70       1
# ..          ...     ...
# 393          82       1
# 394          82       2
# 395          82       1
# 396          82       1
# 397          82       1
#
# [398 rows x 8 columns]

# %%
# check the shape of the DataFrame (rows, columns)
df_training.shape
# Out:
# (398, 8)

# %%
df_training.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %% [markdown]
# check for datatypes
# - look for any string/char (OBJECT)
#     - ML does not accept the OBJECT columns
#         - OBJECT -> numeric (ENCODING)

# %%
df_training.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# dtype: object

# %%
np.unique(df_training['horsepower'])
# Out:
# array(['100', '102', '103', '105', '107', '108', '110', '112', '113',
#        '115', '116', '120', '122', '125', '129', '130', '132', '133',
#        '135', '137', '138', '139', '140', '142', '145', '148', '149',
#        '150', '152', '153', '155', '158', '160', '165', '167', '170',
#        '175', '180', '190', '193', '198', '200', '208', '210', '215',
#        '220', '225', '230', '46', '48', '49', '52', '53', '54', '58',
#        '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70',
#        '71', '72', '74', '75', '76', '77', '78', '79', '80', '81', '82',
#        '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93',
#        '94', '95', '96', '97', '98', '?'], dtype=object)

# %%
df_training[df_training['horsepower'] == '?']
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 32   25.0          4          98.0          ?    2046          19.0
# 126  21.0          6         200.0          ?    2875          17.0
# 330  40.9          4          85.0          ?    1835          17.3
# 336  23.6          4         140.0          ?    2905          14.3
# 354  34.5          4         100.0          ?    2320          15.8
# 374  23.0          4         151.0          ?    3035          20.5
#
#      model year  origin
# 32           71       1
# 126          74       1
# 330          80       2
# 336          80       1
# 354          81       2
# 374          82       1

# %% [markdown]
# #### ASDFGWhat do we do with the "?" in the horsepower column?
#
# 1. drop the rows which have the "?" in the horsepower column
#
# 2. replace the "?" in the horsepower column
#
#     - average value
#     - fixed value
#     - predict for each of "?" (using KNN) - ADVANCE OPTION

# %% [markdown]
# ##### option 2 : We shall fill in the ? values with the average value in the horsepower column

# %%
# get the indexes of the rows where horsepower = '?'
# drop the rows (above indexes)
indx = df_training[df_training['horsepower'] == '?'].index
indx
# Out:
# Index([32, 126, 330, 336, 354, 374], dtype='int64')

# %%
df_without_qs_mark = df_training[df_training['horsepower'] != '?'].copy()

# %%
df_without_qs_mark
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin
# 0            70       1
# 1            70       1
# 2            70       1
# 3            70       1
# 4            70       1
# ..          ...     ...
# 393          82       1
# 394          82       2
# 395          82       1
# 396          82       1
# 397          82       1
#
# [392 rows x 8 columns]

# %%
df_without_qs_mark['horsepower'] = df_without_qs_mark['horsepower'].astype('float64')

# %%
df_without_qs_mark.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model year      origin
# count    392.000000  392.000000  392.000000
# mean      15.541327   75.979592    1.576531
# std        2.758864    3.683737    0.805518
# min        8.000000   70.000000    1.000000
# 25%       13.775000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# 75%       17.025000   79.000000    2.000000
# max       24.800000   82.000000    3.000000

# %% [markdown]
# replace the ? values in df_training with 104.469388

# %%
mask = df_training.horsepower == '?'

# %%
df_training.loc[mask, 'horsepower'] = 104.469

# %%
df_training['horsepower'] = df_training['horsepower'].astype('float64')

# %%
df_training[df_training['horsepower'] == '?']
# Out:
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, model year, origin]
# Index: []

# %%
df_training.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# dtype: object

# %%
import seaborn as sns

# %% [markdown]
# #### 1. check for linearity of the data
#
# - Column X must have linear pattern with the y column
#     - X = ['mpg', 'cylinders', 'displacement', 'weight', 'acceleration', 'year', 'origin']
#     - y = 'horsepower'

# %%
sns.pairplot(df_training,
             x_vars= ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model year', 'origin'], 
             y_vars='horsepower', 
             height=10, 
             aspect=.5, 
             #kind='reg'
            )

# %%
np.unique(df_training['origin'])
# Out:
# array([1, 2, 3], dtype=int64)

# %% [markdown]
# Some comments on `origin` col
# - looks like code for the country of make of the car
#     - US , Canada, Japan..
#
# - data is ordinal
#     - but the name of col suggests we dont need ORDINALITY

# %% [markdown]
# ##### convert the `origin` column to one_hot encoding format

# %%
df_training.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# dtype: object

# %% [markdown]
# so we need to convert the `origin` col to OBJECT type - so we can apply OHE

# %%
df_training['origin'] = df_training['origin'].astype('object')

# %%
df_training.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model year        int64
# origin           object
# dtype: object

# %%
df_training_dummies = pd.get_dummies(df_training, drop_first = False)

# %%
df_training_dummies.sample(5)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 45   18.0          6         258.0       110.0    2962          13.5
# 128  15.0          6         250.0       100.0    3336          17.0
# 120  19.0          4         121.0       112.0    2868          15.5
# 253  20.5          6         200.0        95.0    3155          18.2
# 272  23.8          4         151.0        85.0    2855          17.6
#
#      model year  origin_1  origin_2  origin_3
# 45           71      True     False     False
# 128          74      True     False     False
# 120          73     False      True     False
# 253          78      True     False     False
# 272          78      True     False     False

# %% [markdown]
# #### 2. check for correlation

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(16, 6))
sns.heatmap(df_training_dummies.corr(), annot=True);

# %% [markdown]
# #### 3. build our ML model (regression)

# %% [markdown]
# - prepare the data for training and testing

# %%
# create a Python list of feature names
feature_cols = ['mpg', 'cylinders', 'displacement', 'weight', 'acceleration', 'origin_2','origin_3']

# use the list to select a subset of the original DataFrame
X = df_training_dummies[feature_cols]

# select a Series from the DataFrame
y = df_training_dummies['horsepower']

# %% [markdown]
# - holdout method for evaluation

# %%
from sklearn.model_selection import train_test_split

# %%
# Splitting X and y into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.3)

# %%
# default split is 75% for training and 25% for testing
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (278, 7)
# (278,)
# (120, 7)
# (120,)

# %% [markdown]
# - commission our ML model

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# the model
# - horsepower =  b0
#                 b1 * mpg +
#                 b2 * cylinders +
#                 b3 * displacement +
#                 b4 * weight +
#                 b5 * acceleration +
#                 b6 * year +
#                 b7 * origin

# %% [markdown]
# #### Evaluation of the model

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# - use regression metrics to judge the goodness of the model

# %%
from sklearn import metrics

# %%
# Model evaluation metrics for regression
# print('y-intercept             : ', linreg.intercept_)
# print('beta coefficients       : ', linreg.coef_)
print('Mean Abs Error   MAE    : ', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Sq  Error MSE      : ', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Sq Error RMSE : ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('MAPE                    : ', np.mean(np.abs((y_test - y_pred) / y_test)) * 100)
print('MPE                     : ', np.mean((y_test - y_pred) / y_test) * 100)
print('r2 value                : ', metrics.r2_score(y_test, y_pred))
# Out:
# Mean Abs Error   MAE    :  9.06114352989482
# Mean Sq  Error MSE      :  167.89682741415805
# Root Mean Sq Error RMSE :  12.957500816675955
# MAPE                    :  8.39497428947884
# MPE                     :  -2.0119556436055075
# r2 value                :  0.892176907631497

# %%
y.describe()
# Out:
# count    398.000000
# mean     104.469382
# std       38.199187
# min       46.000000
# 25%       76.000000
# 50%       95.000000
# 75%      125.000000
# max      230.000000
# Name: horsepower, dtype: float64

# %% [markdown]
# #### Summary
#
# In this model, the horsepower column which "?", were not dropped. Instead we replaced the "?" mark with the mean value of the column
#
# the outcome of the model is slightly `degraded` compared to the model where the horsepower = "?" are dropped
#
#
# Key principle is
# - DO NOT DROP ROWS

# %%
import pandas as pd
import scipy.stats as stats

# %%
# Load your dataset (replace with actual path or DataFrame if already loaded)
# Example: df = pd.read_csv("auto-mpg.csv")

# Drop rows with missing horsepower values (if any)
df = df_training.dropna(subset=['horsepower'])

# Group horsepower values by origin
groups = [group["horsepower"].values for name, group in df.groupby("origin")]

# Perform one-way ANOVA
f_statistic, p_value = stats.f_oneway(*groups)

# Display results
print(f"F-statistic: {f_statistic:.4f}")
print(f"P-value: {p_value:.4f}")
# Out:
# F-statistic: 61.1446
# P-value: 0.0000

# %%
pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.4-cp310-cp310-win_amd64.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in d:\python310\lib\site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in d:\python310\lib\site-packages (from statsmodels) (1.15.2)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in d:\python310\lib\site-packages (from statsmodels) (2.2.3)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Downloading patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: packaging>=21.3 in d:\python310\lib\site-packages (from statsmodels) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\python310\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\python310\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\python310\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Downloading statsmodels-0.14.4-cp310-cp310-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ------ --------------------------------- 1.6/9.8 MB 9.3 MB/s eta 0:00:01
#    -------------- ------------------------- 3.7/9.8 MB 9.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.8/9.8 MB 9.8 MB/s eta 0:00:01
#    ------------------------------- -------- 7.9/9.8 MB 9.7 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.8 MB 9.6 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 9.4 MB/s eta 0:00:00
# Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Installing collected packages: patsy, statsmodels
#
#    ---------------------------------------- 0/2 [patsy]
#    ---------------------------------------- 0/2 [patsy]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    ---------------------------------------- 2/2 [statsmodels]
#
# Successfully installed patsy-1.0.1 statsmodels-0.14.4
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# Perform Tukey HSD
tukey_result = pairwise_tukeyhsd(endog=df['horsepower'],
                                 groups=df['origin'],
                                 alpha=0.05)

print(tukey_result)
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ======================================================
# group1 group2 meandiff p-adj   lower    upper   reject
# ------------------------------------------------------
#      1      2 -37.5728    0.0 -48.2234 -26.9222   True
#      1      3 -38.9793    0.0 -49.1453 -28.8133   True
#      2      3  -1.4065 0.9645 -14.3294  11.5163  False
# ------------------------------------------------------
