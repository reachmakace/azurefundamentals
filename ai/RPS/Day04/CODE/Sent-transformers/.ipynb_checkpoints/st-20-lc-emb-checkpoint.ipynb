# %%
from langchain.embeddings import HuggingFaceEmbeddings, SentenceTransformerEmbeddings

# %%
embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
# Equivalent to SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")

# %%
text1 = "apples."
text2 = "shoes"

# %%
query_result1 = embeddings.embed_query(text1)
query_result2 = embeddings.embed_query(text2)

# %%
doc_text1 = embeddings.embed_documents([text, "This is not a test document."])

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Calculate cosine similarity
cosine_sim = np.dot(query_result1, query_result2) / (np.linalg.norm(query_result1) * np.linalg.norm(query_result2))

print("Cosine Similarity:", cosine_sim)
# Out:
# Cosine Similarity: 0.36407691599150765
