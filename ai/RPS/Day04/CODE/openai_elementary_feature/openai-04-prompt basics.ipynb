# %% [markdown]
# -------------------------
# #### Prompt Engg
#
# - basic example using `chat completions`
# - code contains exmaples from 0.28 and later 1.35/1.45 versions of API
# --------------------

# %%
#pip install openai==1.45

# %%
import os
import openai

# %%
openai.__version__
# Out:
# '1.97.1'

# %% [markdown]
# #### models in openAI
# ------------------------------------
#
# OpenAI provides a variety of models, each suited for different use cases, ranging from text generation, code generation, to specific tasks like question answering, summarization, and more.
#
# | Model Type               | Description                                                                                       | Model ID               | Variants/Use Cases                                           |
# |--------------------------|---------------------------------------------------------------------------------------------------|------------------------|-------------------------------------------------------------|
# | **GPT-4 Models**         | The most advanced language model, designed for a wide range of tasks, including text completion and complex reasoning. | `gpt-4`                | Variants: `gpt-4`, `gpt-4-32k` (larger context window)     |
# | **GPT-3.5 Models**       | A slightly earlier version of the GPT-4 model, used for efficient and high-quality completions across various tasks. | `gpt-3.5-turbo`        |                                                             |
# | **Codex Models**         | Specialized for code generation tasks, including programming in multiple languages.              | `code-davinci-002`, `code-cushman-001` | Use cases: Autocomplete for code, bug fixes, code explanations. |
# | **Text-Davinci Models**  | One of the most capable models for text generation, document completion, and more.              | `text-davinci-003`     | Use cases: Writing, summarization, text generation.         |

# %% [markdown]
# ##### Key Properties of Models:
# - **Token Limit**: Defines how much input and output the model can handle in a single request. For example:
#   - GPT-4 has a context length limit of 8,192 tokens, and `gpt-4-32k` can handle up to 32,768 tokens.
# - **Training Data**: The models are trained on a mixture of publicly available and licensed datasets but have a knowledge cutoff (e.g., GPT-4 has a cutoff in September 2021).
#
# Each model has a balance of capability, efficiency, and cost, and you can select the right one depending on the task you need to perform.

# %% [markdown]
# #### Endpoints
# -----------------------------
#
# - OpenAI provides several API endpoints that enable developers to interact with their models for various tasks such as `text generation`, `conversation`, `code completion`, `embedding generation`, and more.
#
# - Each endpoint serves a different purpose and can be accessed via HTTP requests.

# %% [markdown]
# #### 1. Text Completion (Legacy) Endpoint (`/v1/completions`)
#
# While still technically supported, the Completions endpoint is considered legacy. It directly generates text from a prompt without the conversation history format used in the Chat endpoint.
#
# **API Endpoint**:
# POST https://api.openai.com/v1/completions
#
# **Usage**:
# Legacy usage for tasks like document completion, content generation, and summarization.
#
# **Key Parameters**:
# - `model`: Specifies the model (e.g., `text-davinci-003`).
# - `prompt`: The input text to be completed.
# - `max_tokens`: The number of tokens to generate.
# - `temperature`: Controls randomness in the output (higher value = more creative, lower = more deterministic).

# %%
import openai

# %%
# for older 0.28 API
# Make a request to the Completions Endpoint
# response = openai.Completion.create(
#   model       = "gpt-3.5-turbo",                                # Specify the model you want to use
#   prompt      = "Once upon a time, there was a wise owl that",  # Input prompt
#   max_tokens  = 50,                                             # The maximum number of tokens to generate
#   temperature = 0.7,                                            # Controls randomness (0.7 = moderate creativity)
#   n           = 1,                                              # The number of completions to generate
#   stop        = None                                            # Optional stop sequence
# )

# %%
# Print the generated completion
# print(response['choices'][0]['message']['content'])

# %%
# def get_completion(prompt, model="gpt-3.5-turbo"):
#     messages = [{"role": "user", "content": prompt}]
#     response = openai.ChatCompletion.create(                            # older 0.28 
#         model      = model,
#         messages   = messages,
#         temperature= 0, # this is the degree of randomness of the model's output
#     )
#     return response.choices[0].message["content"]

# %%
# prompt = """
# Translate the following English sentence to French:

# 'Hello, world!'
# """

# %%
# response = get_completion(prompt)
# print(response)

# %% [markdown]
# #### 2. Chat Completion Endpoint (/v1/chat/completions)
#
# **Purpose**: Designed for GPT models (GPT-3.5, GPT-4) to handle conversation-like inputs, but can be used for tasks similar to text generation.
#
# **API Endpoint**: POST https://api.openai.com/v1/chat/completions

# %% [markdown]
# **Usage**: It’s the recommended endpoint for most tasks, including text completion, Q&A, summarization, etc., by providing a chat history as input.
#
# **Key Parameters**:
#
# - **model**: Specifies the model to be used (e.g., gpt-4 or gpt-3.5-turbo).
# - **messages**: A list of messages, where each message contains:
#   - **role**: Either "system", "user", or "assistant".
#   - **content**: The text for the message.
# - **max_tokens**: Controls how many tokens to generate.
# - **temperature**: Controls randomness in the output (higher value = more random).

# %%
from openai import OpenAI

# %%
# openai_key = '' # michael

# %%
client = OpenAI(
    # defaults to os.environ.get("OPENAI_API_KEY")
    # api_key = openai_key
)

# %%
# Make a request to the Chat Completion Endpoint
response = client.chat.completions.create(
    model   ="gpt-3.5-turbo",  # Specify the model
    messages=[
        {"role": "user", "content": "Can you summarize the key parameters for the Chat Completion Endpoint?"}
    ],
    max_tokens = 50,
    temperature= 0.7
)

# %%
print(response.choices[0].message.content)
# Out:
# Sure! The key parameters for the Chat Completion Endpoint typically include:
#
# 1. Chat ID: A unique identifier for the chat session.
# 2. Customer ID: An identifier for the customer engaging in the chat.
# 3. Agent ID: An identifier for the

# %% [markdown]
# #### Messages

# %% [markdown]
# In OpenAI's API for language models, messages are the fundamental building blocks of prompts.
#
# Each message typically consists of two main components: the `role` of the sender and the `content` of the message.
#
# | **Role**   | **Description**                                                                                                                                                 | **Example**                                                                                                                  |
# |------------|-----------------------------------------------------------------------------------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------------------------------------|
# | User       | Represents the end user or the application initiating the conversation. Sends input messages, asking questions or providing information for the model's response. | If a user asks, "What is machine learning?", the message is sent with the role of "user".                                  |
# | Assistant  | Represents the AI model's responses to the user’s queries. Generates replies based on the context and content of previous messages, aiming to be helpful and informative. | After the user asks about machine learning, the assistant might respond, "Machine learning is a subset of artificial intelligence that focuses on building systems that learn from data." |
# | System     | Provides initial instructions or context to the assistant to guide its behavior throughout the interaction. Typically used to set the tone, rules, or constraints of the assistant’s responses. | A system message might state, "You are a friendly and informative assistant."                                              |

# %%
[
  {"role": "system",    "content": "You are a knowledgeable assistant in medical domain"},
  {"role": "user",      "content": "Can you tell me about neural networks?"},
  {"role": "assistant", "content": "Neural networks are a series of algorithms that mimic \
                                    the operations of a human brain to recognize relationships in a set of data."}
]
# Out:
# [{'role': 'system',
#   'content': 'You are a knowledgeable assistant in medical domain'},
#  {'role': 'user', 'content': 'Can you tell me about neural networks?'},
#  {'role': 'assistant',
#   'content': 'Neural networks are a series of algorithms that mimic                                     the operations of a human brain to recognize relationships in a set of data.'}]

# %%
client = openai.OpenAI(
    #api_key=openai_api_key
)

# %% [markdown]
# Example

# %%
completion = client.chat.completions.create (
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": "You are a poetic assistant, skilled in explaining complex programming concepts \
                                   with creative flair."},
    {"role": "user",   "content": "Compose a poem that explains the concept of recursion in programming, \
                                   in max 50 words"}
  ]
)

# %% [markdown]
# type(completion)

# %%
completion
# Out:
# ChatCompletion(id='chatcmpl-CDlQNr0c7PqWWaQ1j97Fn1fVGSu3w', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='In the echoing realms of code, recursion reigns,\nA dance of self-reference, where beauty remains.\nLike a mirror reflecting upon itself with grace,\nFunctions calling upon themselves in an endless embrace.\nInfinite loops of patterns, a programming delight,\nRecursion unveils its magic, a recursive flight.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1757396599, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=60, prompt_tokens=46, total_tokens=106, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
def show_result(response):
    print(response.choices[0].message.content)
    return response.choices[0].message.content

# %%
res= show_result(completion)
# Out:
# In the echoing realms of code, recursion reigns,
# A dance of self-reference, where beauty remains.
# Like a mirror reflecting upon itself with grace,
# Functions calling upon themselves in an endless embrace.
# Infinite loops of patterns, a programming delight,
# Recursion unveils its magic, a recursive flight.

# %% [markdown]
# #### Deciphering the completion response object

# %%
import json
from pprint import pprint

# %%
# Pretty print the response using pprint
pprint(response.to_dict())
# Out:
# {'choices': [{'finish_reason': 'length',
#               'index': 0,
#               'logprobs': None,
#               'message': {'annotations': [],
#                           'content': 'Sure! The key parameters for the Chat '
#                                      'Completion Endpoint typically include:\n'
#                                      '\n'
#                                      '1. Chat ID: A unique identifier for the '
#                                      'chat session.\n'
#                                      '2. Customer ID: An identifier for the '
#                                      'customer engaging in the chat.\n'
#                                      '3. Agent ID: An identifier for the',
#                           'refusal': None,
#                           'role': 'assistant'}}],
#  'created': 1757396597,
#  'id': 'chatcmpl-CDlQLrraraO6dpX38Lhth9ZN3nvz9',
#  'model': 'gpt-3.5-turbo-0125',
#  'object': 'chat.completion',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'usage': {'completion_tokens': 50,
#            'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                          'audio_tokens': 0,
#                                          'reasoning_tokens': 0,
#                                          'rejected_prediction_tokens': 0},
#            'prompt_tokens': 19,
#            'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0},
#            'total_tokens': 69}}

# %%
# Serialize to JSON and print
json_output = json.dumps(response.to_dict(), indent=4)
print(json_output)
# Out:
# {
#     "id": "chatcmpl-CDlQLrraraO6dpX38Lhth9ZN3nvz9",
#     "choices": [
#         {
#             "finish_reason": "length",
#             "index": 0,
#             "logprobs": null,
#             "message": {
#                 "content": "Sure! The key parameters for the Chat Completion Endpoint typically include:\n\n1. Chat ID: A unique identifier for the chat session.\n2. Customer ID: An identifier for the customer engaging in the chat.\n3. Agent ID: An identifier for the",
#                 "refusal": null,
#                 "role": "assistant",
#                 "annotations": []
#             }
#         }
#     ],
#     "created": 1757396597,
#     "model": "gpt-3.5-turbo-0125",
#     "object": "chat.completion",
#     "service_tier": "default",
#     "system_fingerprint": null,
#     "usage": {
#         "completion_tokens": 50,
#         "prompt_tokens": 19,
#         "total_tokens": 69,
#         "completion_tokens_details": {
#             "accepted_prediction_tokens": 0,
#             "audio_tokens": 0,
#             "reasoning_tokens": 0,
#             "rejected_prediction_tokens": 0
#         },
#         "prompt_tokens_details": {
#             "audio_tokens": 0,
#             "cached_tokens": 0
#         }
#     }
# }

# %% [markdown]
# #### Attributes of ChatCompletion
#
# | Attribute          | Description                                                                                  |
# |--------------------|----------------------------------------------------------------------------------------------|
# | **id**             | A unique identifier for the completion request (e.g., `'chatcmpl-ABc5tNfn75ylhDfYoCrEBNlqk6xqO'`). |
# | **choices**        | A list of `Choice` objects representing the different responses generated by the model. In this case, there is one choice. |
# | **created**        | A timestamp indicating when the completion was created (e.g., `1727331405`).               |
# | **model**          | The model used to generate the completion (e.g., `'gpt-3.5-turbo-0125'`).                   |
# | **object**         | The type of object, which indicates it's a `chat.completion`.                               |
# | **usage**          | An object that details the token usage for the request and response, including:            |
# |                    | - **completion_tokens**: Number of tokens used in the completion (e.g., `45`).              |
# |                    | - **prompt_tokens**: Number of tokens used in the input prompt (e.g., `46`).               |
# |                    | - **total_tokens**: Total number of tokens used (e.g., `91`).                              |

# %% [markdown]
# **Choices**
#
# | Attribute               | Description                                                                                              |
# |-------------------------|----------------------------------------------------------------------------------------------------------|
# | **finish_reason**        | The reason the completion finished (e.g., `'stop'`).                                                     |
# | **index**                | The index of the choice in the list.                                                                     |
# | **logprobs**             | Any associated log probabilities (in this case, it's `None`).                                            |
# | **message**              | An instance of `ChatCompletionMessage` that contains:                                                    |
# | - **content**            | The actual text generated by the model (e.g., a poem about recursion).                                   |
# | - **role**               | The role of the entity that generated the message (e.g., `'assistant'`).                                 |
# | - **function_call**      | Information if the message included a function call (in this case, it's `None`).                         |
# | - **tool_calls**         | Information if there were any tool calls (also `None` in this case).                                     |

# %% [markdown]
# #### Exercise - 01
#
# - (extract pieces of info from the completion response)

# %%
response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user",   "content": "Who won the world series in 2020?"},
    ]
)

# %%
res = show_result(response)
# Out:
# The Los Angeles Dodgers won the World Series in 2020. They defeated the Tampa Bay Rays in six games to win their first championship since 1988.

# %% [markdown]
# Qs : Extract the model name from the response object.

# %%
# Expected solution
model_name = response.to_dict()['model']
print("Model used:", model_name)
# Out:
# Model used: gpt-3.5-turbo-0125

# %% [markdown]
# Qs : Extract the content of the assistant’s reply from the response object.

# %%
# Expected solution
assistant_reply = response.to_dict()['choices'][0]['message']['content']
print("Assistant's reply:", assistant_reply)
# Out:
# Assistant's reply: The Los Angeles Dodgers won the World Series in 2020. They defeated the Tampa Bay Rays in six games to win their first championship since 1988.

# %% [markdown]
# let us change the prompt to add a few more years ...

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user",   "content": "Who won the world series in 2020, 2021, 2022, 2023 ?"},
    ]
)

# %% [markdown]
# Qs : Create a dictionary of World Series winners by year from the assistant’s reply.

# %%
# Example solution
winners_by_year = response.to_dict()['choices'][0]['message']['content']
print(winners_by_year)
# Out:
# The winners of the World Series for the specified years are:
#
# - **2020**: Los Angeles Dodgers
# - **2021**: Atlanta Braves
# - **2022**: Houston Astros
# - **2023**: Texas Rangers
#
# If you need more information about any of these championships, feel free to ask!

# %% [markdown]
# Get the output in a dictionary format, year : winner name

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user",   "content": "Who won the world series in 2020, 2021, 2022, 2023 ? \
                                       Provide the answer in a dictionary format as below \
                                       year : winner name \
                                       "},
    ]
)

# %%
# Example solution
winners_by_year = response.to_dict()['choices'][0]['message']['content']
print(winners_by_year)
# Out:
# Here is the requested information in dictionary format:
#
# ```python
# {
#     2020: "Los Angeles Dodgers",
#     2021: "Atlanta Braves",
#     2022: "Houston Astros",
#     2023: "Texas Rangers"
# }
# ```

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user",   "content": '''Who won the world series in 2020, 2021, 2022, 2023 ? \
                                       Provide the answer in a dictionary format as below \
                                       {
                                           year : winner name 
                                       }
                                       without any extra text
                                       \
                                       '''},
    ]
)

# %% [markdown]
# Qs : load the output in dataframe format

# %% [markdown]
# | Year | Winner                |
# |------|-----------------------|
# | 2020 | Los Angeles Dodgers   |
# | 2021 | Atlanta Braves        |
# | 2022 | Houston Astros        |
# | 2023 | Texas Rangers         |

# %%
# Example solution
winners_by_year = response.to_dict()['choices'][0]['message']['content']
winners_by_year
# Out:
# '{\n    2020: "Los Angeles Dodgers",\n    2021: "Atlanta Braves",\n    2022: "Houston Astros",\n    2023: "Texas Rangers"\n}'

# %%
import pandas as pd
import ast

# %%
# Convert the string representation of the dictionary to an actual dictionary
world_series_dict = ast.literal_eval(winners_by_year)

# %%
world_series_dict
# Out:
# {2020: 'Los Angeles Dodgers',
#  2021: 'Atlanta Braves',
#  2022: 'Houston Astros',
#  2023: 'Texas Rangers'}

# %%
# Load the dictionary into a pandas DataFrame
df = pd.DataFrame(list(world_series_dict.items()), columns=['Year', 'Winner'])
df
# Out:
#    Year               Winner
# 0  2020  Los Angeles Dodgers
# 1  2021       Atlanta Braves
# 2  2022       Houston Astros
# 3  2023        Texas Rangers

# %% [markdown]
# Qs : Extract only the winner names from the dictionary and store them in a list.

# %%
# Convert to dictionary
world_series_dict = ast.literal_eval(winners_by_year)

# %%
# Extract winners
winners = list(world_series_dict.values())
winners
# Out:
# ['Los Angeles Dodgers', 'Atlanta Braves', 'Houston Astros', 'Texas Rangers']

# %% [markdown]
# Qs : Convert the dictionary into a list of tuples with (Year, Winner).

# %%
# Convert to dictionary
world_series_dict = ast.literal_eval(winners_by_year)

# %%
# Convert to list of tuples
year_winner_tuples = list(world_series_dict.items())
year_winner_tuples
# Out:
# [(2020, 'Los Angeles Dodgers'),
#  (2021, 'Atlanta Braves'),
#  (2022, 'Houston Astros'),
#  (2023, 'Texas Rangers')]

# %% [markdown]
# Qs : Write a function that checks if a given team won the World Series in a specified year.

# %%
def did_team_win(year, team):
    return world_series_dict.get(year) == team

# %%
# Example usage:
print(did_team_win(2020, "Los Angeles Dodgers"))  # Expected: True
print(did_team_win(2021, "Los Angeles Dodgers"))  # Expected: False
# Out:
# True
# False

# %% [markdown]
# Qs : Find the most recent World Series winner

# %%
# Find the most recent year
most_recent_year = max(world_series_dict.keys())

# %%
# Get the winner of the most recent year
most_recent_winner = world_series_dict[most_recent_year]

# Print the most recent winner
print(f"The most recent winner is {most_recent_winner} in {most_recent_year}.")
# Out:
# The most recent winner is Texas Rangers in 2023.

# %% [markdown]
# #### Finish Reason Summary
#
# | Finish Reason      | Description                                                                                                            | Example                             |
# |--------------------|------------------------------------------------------------------------------------------------------------------------|-------------------------------------|
# | "stop"             | The model completed its response naturally, reaching a logical stopping point like the end of a sentence or thought.  | "finish_reason": "stop"            |
# | "length"           | The response was cut off because the model reached the maximum number of tokens allowed in the API request.            | "finish_reason": "length"          |
# | "content_filter"   | The response was stopped because it triggered the safety filter, likely due to generating inappropriate or unsafe content. | "finish_reason": "content_filter"  |
# | null               | The completion ended for an unknown or unspecified reason, or there was no particular reason captured (rare, edge case scenario). | "finish_reason": null               |

# %% [markdown]
# #### Index Attribute Summary
#
# | Index | Description                                                                                      | Example                 |
# |-------|--------------------------------------------------------------------------------------------------|-------------------------|
# | 0     | The index of the choice in the list of choices returned by the model. It typically starts at 0. | "index": 0              |
# | 1     | Indicates the second choice in the list, if multiple choices are generated.                      | "index": 1              |
# | 2     | Represents the third choice in the list of generated responses, if applicable.                   | "index": 2              |
# | ...   | Continues incrementing for additional choices returned, based on the number of choices.         | "index": n (where n is the choice number) |

# %% [markdown]
# #### Message Attribute Summary
#
# | Attribute         | Description                                                                                             | Example                                                              |
# |-------------------|---------------------------------------------------------------------------------------------------------|----------------------------------------------------------------------|
# | content           | The actual text generated by the model, representing the response.                                     | "content": "This is the generated text."                            |
# | role              | Indicates the role of the entity that generated the message, typically "assistant" for model responses.| "role": "assistant"                                                 |
# | function_call     | Contains information about any function calls included in the message, if applicable (otherwise None).| "function_call": None                                               |
# | tool_calls        | Provides information about any tool calls made during the response generation (usually None).          | "tool_calls": None                                                  |

# %% [markdown]
# #### Reasoning abilities

# %%
context = '''
during the start of the training program, the learners were asked if they wished certain AI topics or lessons
they would like the instructor to provide a quick recap or brush up and illustrations. Based of their feedback
the instructor captured list of topics for the recap. The agreed assumption was that the learners are familiar with
the topics but needed a quick refresher on them. The instructor provided walk thru on each of the topics with examples and illustration 
with python codes and gave them time of 5 mins on each topic if they had any qs or difficulties. During the entire 4 sessions the learners
do not complaing about understanding the concepts, code, examples even after being polled explicitly for their repsonse.
But a couple of them provide feedback at the end of the week to their manager, instead. leaving the instructor completely unaware.
'''

feedback = '''
the trainer’s pace was slower than expected, and it seemed like he was copying code from his notebook 
without providing sufficient explanations on the "what" and "why" behind the actions. 
need for more in-depth explanations and context.
'''

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are a helpful assistant with abilities to interpret learners' feedback."},
        {"role": "user", "content": f"Based on the {context}, assess if there are contradictions in the {feedback}. \
        Provide a clear explanation of your understanding of the feedback \
        Provide areas where learners could have helped the trainer in the recap sessions"}
    ],
    temperature=0.1
)

# %%
print(response.to_dict()['choices'][0]['message']['content'])
# Out:
# Based on the feedback provided, there are indeed contradictions in the learners' responses and the instructor's perception of their understanding. Here’s a breakdown of the situation:
#
# ### Understanding of the Feedback
#
# 1. **Initial Assumption of Familiarity**: The instructor assumed that the learners were familiar with the topics and only needed a quick refresher. This assumption was based on the learners' initial request for a recap.
#
# 2. **Lack of Explicit Complaints**: Throughout the training sessions, the learners did not express any complaints or difficulties during the Q&A sessions. This led the instructor to believe that the learners were satisfied with the pace and content of the training.
#
# 3. **Contradictory Feedback**: Despite the lack of complaints during the sessions, some learners provided feedback to their manager indicating that the trainer's pace was slower than expected and that there was a lack of sufficient explanations regarding the "what" and "why" of the code being presented. This suggests that while learners may not have felt comfortable voicing their concerns in the moment, they still had significant issues with the training.
#
# 4. **Need for In-Depth Explanations**: The feedback indicates that learners were looking for more context and depth in the explanations provided, rather than just a walkthrough of the code. This highlights a gap between the instructor's approach and the learners' expectations.
#
# ### Areas Where Learners Could Have Helped the Trainer
#
# 1. **Providing Real-Time Feedback**: Learners could have been encouraged to provide immediate feedback during the sessions. This could have been facilitated through anonymous polls or feedback forms after each topic, allowing them to express their concerns without fear of judgment.
#
# 2. **Asking Clarifying Questions**: If learners felt that certain explanations were lacking, they could have asked more clarifying questions during the Q&A sessions. This would have given the instructor an opportunity to address their concerns on the spot.
#
# 3. **Setting Expectations**: At the beginning of the recap sessions, learners could have articulated their expectations more clearly. If they were looking for deeper explanations, stating this upfront would have guided the instructor's approach.
#
# 4. **Engaging in Discussions**: Encouraging a more interactive environment where learners could discuss their thoughts and experiences related to the topics could have provided the instructor with insights into their understanding and needs.
#
# 5. **Feedback Mechanism**: Establishing a structured feedback mechanism, such as a dedicated feedback session or a shared document where learners could jot down their thoughts throughout the training, could have helped the instructor gauge the learners' understanding and adjust accordingly.
#
# ### Conclusion
#
# The situation highlights the importance of open communication and feedback in a learning environment. While the instructor believed the learners were satisfied, the lack of vocal feedback during sessions led to a disconnect between their needs and the training provided. Encouraging learners to engage more actively and providing avenues for feedback could enhance the effectiveness of future training sessions.

# %% [raw]
# Based on the feedback provided, there are several key points to consider regarding the learners' experience during the training program:
#
# ### Understanding of the Feedback
#
# 1. **Initial Assumption vs. Actual Experience**: The instructor assumed that learners were familiar with the topics and only needed a quick refresher. However, the feedback suggests that while learners did not express difficulties during the sessions, they may not have fully understood the material due to a lack of depth in explanations.
#
# 2. **Pace of Instruction**: The feedback indicates that the trainer's pace was slower than expected, which could imply that learners felt the sessions were dragging or not engaging enough. This could lead to frustration, especially if they were looking for a more dynamic or interactive learning experience.
#
# 3. **Code Explanation**: The comment about the instructor copying code from his notebook without sufficient explanations highlights a disconnect between the learners' expectations and the instructor's delivery. Learners may have wanted more context about the code—specifically, the rationale behind certain coding choices and how they relate to the concepts being taught.
#
# 4. **Feedback Mechanism**: The fact that learners chose to provide feedback to their manager instead of directly to the instructor suggests a lack of open communication. This could indicate that learners did not feel comfortable voicing their concerns in real-time or that they did not believe their feedback would lead to changes.
#
# ### Areas Where Learners Could Have Helped the Trainer
#
# 1. **Real-Time Feedback**: Learners could have been encouraged to provide immediate feedback during the sessions. This could have been facilitated through anonymous polls or feedback forms after each topic, allowing the instructor to adjust the pace or depth of explanations as needed.
#
# 2. **Clarifying Expectations**: At the beginning of the training, learners could have articulated their expectations more clearly. If they were looking for deeper explanations or more context, expressing this upfront could have guided the instructor's approach.
#
# 3. **Asking Questions**: While the instructor provided time for questions, learners could have been more proactive in asking for clarification on specific points where they felt explanations were lacking. This would have helped the instructor identify areas that needed more attention.
#
# 4. **Providing Constructive Feedback**: Instead of waiting until the end of the week to provide feedback to their manager, learners could have shared their thoughts directly with the instructor. Constructive feedback during the sessions could have allowed the instructor to make adjustments in real-time.
#
# 5. **Engagement in Discussions**: Learners could have engaged more in discussions or group activities during the recap sessions. This could have fostered a more interactive environment where learners could share their understanding and clarify doubts collectively.
#
# In summary, while the instructor aimed to provide a recap based on the assumption of prior knowledge, the feedback indicates that learners may have needed more in-depth explanations and context. Encouraging open communication and real-time feedback could have enhanced the learning experience for everyone involved.

# %% [markdown]
# ## Useful applications of messaging structure
# ------------------------------------

# %%
# Initialize the conversation with a system message
conversation = [
    {"role": "system", "content": "You are a helpful assistant."}
]

# %%
def send_message(conversation):
    # Send the conversation to the OpenAI API and get a response
    
    response = client.chat.completions.create(
        model    = "gpt-3.5-turbo",
        messages = conversation
    )
    return response.to_dict()['choices'][0]['message']['content']

# %%
# Add user messages incrementally
user_inputs = [
    "What is the capital of France?",
    "Can you tell me more about its culture?",
    "What are some famous landmarks there?",
    "How is the cuisine different from other countries?",
    "What is the best time of year to visit?"
]

# %%
# Iterate through user inputs
for user_input in user_inputs:
    conversation.append({"role": "user", "content": user_input})
    
    # Get assistant's response
    assistant_response = send_message(conversation)
    
    conversation.append({"role": "assistant", "content": assistant_response})
    
    # Print the latest response
    print("User:", user_input)
    print("Assistant:", assistant_response)
    print("-" * 50)  # Separator for clarity
# Out:
# User: What is the capital of France?
# Assistant: The capital of France is Paris.
# --------------------------------------------------
# User: Can you tell me more about its culture?
# Assistant: Certainly! France has a rich and diverse culture that has had a significant influence worldwide. French culture is known for its art, fashion, cuisine, literature, architecture, and music.
#
# Art: France has a long history of producing famous artists, including painters like Claude Monet, Edgar Degas, and Paul Cézanne. The country also boasts world-renowned museums like the Louvre and the Musée d'Orsay.
#
# Fashion: France is considered a global hub for fashion, with Paris being known as one of the fashion capitals of the world. The city hosts prestigious fashion events such as Paris Fashion Week and is home to many luxury fashion houses.
#
# Cuisine: French cuisine is celebrated for its sophistication and variety. It includes dishes such as coq au vin, boeuf bourguignon, croissants, and an array of cheeses and wines. The French take pride in their culinary traditions and consider mealtime a social and cultural experience.
#
# Literature: France has a rich literary history with famous writers like Victor Hugo, Gustave Flaubert, and Albert Camus. French literature has made significant contributions to world literature, with genres ranging from novels and poetry to philosophical essays.
#
# Architecture: France is renowned for its architectural landmarks, such as the iconic Eiffel Tower, Notre-Dame Cathedral, and Palace of Versailles. The country's architecture reflects various styles, from medieval cathedrals to modernist structures.
#
# Music: France has a vibrant music scene that encompasses classical music, opera, chanson (French songs), and electronic music. French musicians and composers like Claude Debussy, Édith Piaf, and Daft Punk have left a lasting impact on the music world.
#
# Overall, French culture values art, sophistication, and a love for the finer things in life. It is a blend of tradition and innovation, creating a unique and dynamic cultural landscape.
# --------------------------------------------------
# User: What are some famous landmarks there?
# Assistant: France is home to many famous landmarks that attract millions of visitors from around the world. Some of the most iconic landmarks in France include:
#
# 1. Eiffel Tower (Tour Eiffel) - A symbol of Paris and one of the most recognized structures in the world, the Eiffel Tower was built in 1889 for the World's Fair and has become synonymous with the city.
#
# 2. Louvre Museum (Musée du Louvre) - One of the largest and most visited museums in the world, the Louvre is home to thousands of works of art, including the famous painting of the Mona Lisa.
#
# 3. Notre-Dame Cathedral - A masterpiece of French Gothic architecture, Notre-Dame Cathedral is located on the Île de la Cité in Paris and is known for its stunning stained glass windows and intricate sculptures.
#
# 4. Palace of Versailles (Château de Versailles) - Once the royal residence of King Louis XIV, the Palace of Versailles is a magnificent example of French Baroque architecture and features opulent gardens and luxurious interior rooms.
#
# 5. Mont Saint-Michel - A breathtaking island commune located off the coast of Normandy, Mont Saint-Michel is known for its medieval abbey perched atop a rocky outcrop, surrounded by the sea at high tide.
#
# 6. Arc de Triomphe - Built to honor those who fought and died for France during the French Revolutionary and Napoleonic Wars, the Arc de Triomphe stands at the western end of the Champs-Élysées in Paris.
#
# 7. Château de Chambord - A grand French Renaissance château located in the Loire Valley, Château de Chambord is known for its distinctive architecture and expansive grounds.
#
# 8. Sainte-Chapelle - A stunning Gothic chapel located on the Île de la Cité in Paris, Sainte-Chapelle is celebrated for its intricate stained glass windows depicting biblical scenes.
#
# These landmarks are just a few examples of the rich historical and architectural heritage that can be found throughout France, showcasing the country's cultural significance and beauty.
# --------------------------------------------------
# User: How is the cuisine different from other countries?
# Assistant: French cuisine is renowned worldwide for its emphasis on quality ingredients, meticulous preparation techniques, and rich culinary traditions. There are several aspects that set French cuisine apart from that of other countries:
#
# 1. Emphasis on Fresh, Seasonal Ingredients: French cuisine places a strong emphasis on using fresh, seasonal ingredients to create flavorful dishes. Locally sourced produce, meats, and seafood are prized for their quality and are often the stars of French dishes.
#
# 2. Culinary Techniques and Skills: French chefs are known for their mastery of culinary techniques, such as sautéing, braising, roasting, and baking. French cooking methods often involve meticulous attention to detail and precision in order to achieve the desired flavors and textures.
#
# 3. Classic French Sauces: French cuisine is famous for its rich and complex sauces that are a hallmark of many French dishes. Sauces like Béchamel, Hollandaise, Velouté, and espagnole form the foundation of French culinary tradition and add depth and flavor to a wide variety of dishes.
#
# 4. Bread and Pastries: Bread plays a central role in French cuisine, with baguettes, croissants, and other baked goods being staples of the French diet. French pastry-making is also highly regarded, with delicate pastries, tarts, and desserts showcasing the country's expertise in the art of baking.
#
# 5. Regional Diversity: France is a country with diverse regional cuisines, each with its own specialties and culinary traditions. From the rich, buttery dishes of Normandy to the Mediterranean-influenced cuisine of Provence, each region of France boasts unique flavors and ingredients.
#
# 6. Dining Culture: French dining is often seen as a social and cultural experience, with meals being savored slowly and enjoyed with wine and good company. The French take pride in their culinary heritage and consider mealtime an opportunity to indulge in good food and conversation.
#
# Overall, French cuisine stands out for its focus on quality ingredients, culinary expertise, and attention to detail, making it a beloved and respected culinary tradition that continues to influence food culture around the world.
# --------------------------------------------------
# User: What is the best time of year to visit?
# Assistant: The best time to visit France depends on your personal preferences and what you hope to experience during your trip. Here are some considerations for different times of the year:
#
# 1. Spring (March to May): Spring is a beautiful time to visit France when the weather starts to warm up, flowers bloom, and outdoor cafes come to life. This season is ideal for exploring gardens, vineyards, and charming countryside villages without the crowds of summer.
#
# 2. Summer (June to August): Summer is the peak tourist season in France, with long days of sunshine, warm temperatures, and a lively atmosphere. This is a great time to visit coastal areas, enjoy outdoor festivals and events, and bask in the beauty of France's many parks and gardens.
#
# 3. Fall (September to November): Fall is another lovely time to visit France, with mild temperatures, colorful foliage, and fewer tourists compared to the summer months. This season is perfect for wine enthusiasts, as it coincides with the grape harvest in many wine regions.
#
# 4. Winter (December to February): Winter in France can be magical, especially in regions like the French Alps where you can enjoy skiing and other winter sports. Cities like Paris also take on a festive atmosphere during the holiday season, with Christmas markets and decorations adding to the charm.
#
# Ultimately, the best time to visit France depends on your interests and what you hope to experience during your trip. Whether you prefer warm weather and outdoor activities, cultural events and festivals, or a quieter travel experience, France offers something special throughout the year.
# --------------------------------------------------

# %%
conversation
# Out:
# [{'role': 'system', 'content': 'You are a helpful assistant.'},
#  {'role': 'user', 'content': 'What is the capital of France?'},
#  {'role': 'assistant', 'content': 'The capital of France is Paris.'},
#  {'role': 'user', 'content': 'Can you tell me more about its culture?'},
#  {'role': 'assistant',
#   'content': "Sure! The culture of France is rich and diverse, spanning centuries of history and influences from various regions and countries. Here are some key aspects of French culture:\n\n1. Art and Literature: France has a long history of being a hub for art and literature. French artists like Claude Monet, Edgar Degas, and Auguste Rodin have made significant contributions to the art world. French literature is also renowned, with authors such as Victor Hugo, Marcel Proust, and Simone de Beauvoir shaping the country's literary landscape.\n\n2. Cuisine: French cuisine is celebrated worldwide for its sophistication and elegance. It is characterized by fresh ingredients, meticulous preparation, and a variety of flavors and techniques. French dishes like coq au vin, boeuf bourguignon, and escargot are famous examples of the country's culinary tradition.\n\n3. Fashion: France is a global trendsetter in the fashion industry, with cities like Paris being synonymous with high fashion. French designers like Coco Chanel, Christian Dior, and Yves Saint Laurent have shaped the fashion world with their iconic designs and styles.\n\n4. Music and Dance: France has a vibrant music scene, encompassing a wide range of genres from classical music to contemporary pop and electronic music. French artists like Édith Piaf, Serge Gainsbourg, and Daft Punk have achieved international acclaim. French dance forms like ballet and cabaret also have a long-standing cultural importance.\n\n5. Architecture: France is home to a wealth of architectural wonders, from iconic landmarks like the Eiffel Tower and Notre-Dame Cathedral to historic châteaux and Roman ruins. The country's architecture reflects its diverse history and cultural influences.\n\nOverall, French culture is characterized by sophistication, creativity, and a deep appreciation for art, cuisine, and intellectual pursuits."},
#  {'role': 'user', 'content': 'What are some famous landmarks there?'},
#  {'role': 'assistant',
#   'content': "France is home to many famous landmarks that attract millions of tourists from around the world each year. Some of the most iconic landmarks in France include:\n\n1. Eiffel Tower (Tour Eiffel) - Located in Paris, the Eiffel Tower is one of the most recognizable symbols of France and a must-visit attraction for visitors to the city.\n\n2. Louvre Museum - Situated in Paris, the Louvre is one of the world's largest and most famous art museums, housing thousands of artworks including the Mona Lisa and the Venus de Milo.\n\n3. Notre-Dame Cathedral - This historic cathedral, also in Paris, is a masterpiece of French Gothic architecture and a UNESCO World Heritage site.\n\n4. Palace of Versailles (Château de Versailles) - Located near Paris, the Palace of Versailles is a stunning example of French Baroque architecture and was once the royal residence of the French monarchy.\n\n5. Mont Saint-Michel - This picturesque island commune in Normandy is known for its medieval architecture and the stunning abbey perched on top of a rocky outcrop.\n\n6. Château de Chambord - Situated in the Loire Valley, this Renaissance château is the largest and most extravagant of the Loire Valley castles, known for its distinctive French architecture.\n\n7. Arc de Triomphe - Another iconic symbol of Paris, the Arc de Triomphe is a triumphal arch located at the western end of the Champs-Élysées.\n\n8. Sainte-Chapelle - This stunning Gothic chapel in Paris is renowned for its exquisite stained glass windows depicting biblical scenes.\n\nThese are just a few of the many famous landmarks that France has to offer, each with its own unique history, architecture, and cultural significance."},
#  {'role': 'user',
#   'content': 'How is the cuisine different from other countries?'},
#  {'role': 'assistant',
#   'content': 'French cuisine is often considered one of the finest and most renowned cuisines in the world, known for its emphasis on fresh, high-quality ingredients, meticulous preparation, and elegant presentation. Here are some key characteristics that set French cuisine apart from other countries:\n\n1. Emphasis on technique: French cooking is highly technique-driven, with a focus on precision and skill in the preparation of dishes. Techniques such as sautéing, braising, poaching, and flambéing are commonly used in French cuisine.\n\n2. Culinary traditions: France has a long culinary tradition that dates back centuries, with regional dishes and local specialties passed down through generations. Each region of France has its own unique culinary specialties, reflecting the influences of local ingredients and cultural heritage.\n\n3. Use of high-quality ingredients: French cuisine places a strong emphasis on using fresh, seasonal ingredients of the highest quality. Locally sourced produce, meats, cheeses, and wines are central to French cooking, and ingredients are often allowed to shine through simple yet flavorful preparations.\n\n4. Rich sauces and flavors: French cuisine is known for its rich, flavorful sauces made from stocks, wines, herbs, and aromatics. Classic French sauces like béchamel, velouté, hollandaise, and béarnaise are staples of French cooking, adding depth and complexity to dishes.\n\n5. Fine dining tradition: France has a strong tradition of fine dining and gastronomy, with a focus on artful presentation, elegant table settings, and multi-course meals. French dining etiquette and formal dining rituals are often observed in both casual and upscale dining settings.\n\n6. Pastry and baking: French pastry and baking techniques are world-renowned for their precision, artistry, and delicate flavors. French pastries like croissants, macarons, éclairs, and tarts are beloved both in France and around the world.\n\nWhile French cuisine has influenced culinary traditions in many countries, its emphasis on technique, quality ingredients, and culinary heritage continue to set it apart as a distinguished and celebrated cuisine globally.'},
#  {'role': 'user', 'content': 'What is the best time of year to visit?'},
#  {'role': 'assistant',
#   'content': 'The best time of year to visit France depends on your preferences and the activities you plan to engage in. Here is a general overview of the different seasons to help you decide:\n\n1. Spring (March to May): Spring is a popular time to visit France, especially in April and May when the weather is mild and flowers are in bloom. This is a great time to explore gardens, vineyards, and outdoor attractions without the peak summer crowds.\n\n2. Summer (June to August): Summer is the peak tourist season in France, with warm weather and longer days ideal for outdoor activities, festivals, and beach vacations. However, popular tourist destinations can be crowded, and prices may be higher during this time.\n\n3. Fall (September to November): Fall is another great time to visit France, with cooler temperatures and colorful foliage making it a picturesque season. September and October are ideal for wine harvest festivals and exploring historic sites with fewer tourists.\n\n4. Winter (December to February): Winter in France can be cold and rainy in some regions but offers the opportunity to experience festive holiday markets, skiing in the Alps, and cozying up by the fireplace in charming villages. Paris is particularly magical during the holiday season.\n\nUltimately, the best time to visit France depends on your preferences for weather, activities, and crowd levels. Consider factors such as seasonal events, outdoor pursuits, and your tolerance for crowds and weather when planning your trip.'}]

# %%
len(conversation)
# Out:
# 11

# %% [markdown]
# **Strategies to Manage Conversation Length**

# %%
# Initialize the conversation with a system message
conversation = [
    {"role": "system", "content": "You are a helpful assistant."}
]

# %%
def send_message(conversation):
    # Send the conversation to the OpenAI API and get a response
    response = client.chat.completions.create(
        model    = "gpt-3.5-turbo",
        messages = conversation
    )
    return response.to_dict()['choices'][0]['message']['content']

# %%
# Add user messages incrementally
user_inputs = [
    "What is the capital of France?",
    "Can you tell me more about its culture?",
    "What are some famous landmarks there?",
    "How is the cuisine different from other countries?",
    "What is the best time of year to visit?"
]

# %%
# Set a limit for how many exchanges to keep
max_history_length = 6  # Total messages to keep (including system message)

# %%
# Flag to indicate if the initial question has been answered
initial_question_responded = False

# %%
# Iterate through user inputs
for user_input in user_inputs:
    conversation.append({"role": "user", "content": user_input})
    
    # Get assistant's response
    assistant_response = send_message(conversation)
    conversation.append({"role": "assistant", "content": assistant_response})
    
    # Print the latest response
    print("User:", user_input)
    print("Assistant:", assistant_response)
    print("-" * 50)  # Separator for clarity

    # Truncate the conversation to the most recent exchanges
    if len(conversation) > max_history_length:
        # Always keep the first question and its response
        if not initial_question_responded:
            # Keep the first user question and its response
            initial_question = conversation[1]  # User question
            initial_response = conversation[2]  # Assistant response
            # Retain them in the conversation
            conversation = [conversation[0], initial_question, initial_response]
            initial_question_responded = True
        else:
            # Keep only the last `max_history_length` messages
            conversation = conversation[-max_history_length:]
# Out:
# User: What is the capital of France?
# Assistant: The capital of France is Paris.
# --------------------------------------------------
# User: Can you tell me more about its culture?
# Assistant: French culture is known for its rich history, art, literature, music, cuisine, and fashion. France has been a major center of art and philosophy for centuries, producing renowned artists such as Claude Monet, Edith Piaf, and Coco Chanel. French cuisine is highly regarded worldwide, with dishes such as croissants, baguettes, escargot, and coq au vin. The country is also known for its wine and cheese.
#
# In addition, French culture places a strong emphasis on family, education, and national pride. The French take pride in their language, French art de vivre (art of living), and their history of revolutions and intellectual movements.
#
# Overall, French culture is diverse and dynamic, blending traditional elements with modern influences to create a vibrant and unique identity.
# --------------------------------------------------
# User: What are some famous landmarks there?
# Assistant: France is home to several iconic landmarks that attract millions of visitors each year. Some of the most famous landmarks in France include:
#
# 1. Eiffel Tower (Tour Eiffel) in Paris - A globally recognized symbol of France, the Eiffel Tower is an iron lattice tower standing at 300 meters tall.
#
# 2. Louvre Museum (Musée du Louvre) in Paris - One of the world's largest and most visited museums, housing thousands of works of art, including the Mona Lisa and the Venus de Milo.
#
# 3. Notre-Dame Cathedral in Paris - A stunning example of French Gothic architecture, Notre-Dame is known for its intricate façade, beautiful stained glass windows, and iconic flying buttresses.
#
# 4. Palace of Versailles (Château de Versailles) near Paris - A former royal residence, the Palace of Versailles is a UNESCO World Heritage site known for its opulent architecture, extensive gardens, and Hall of Mirrors.
#
# 5. Mont Saint-Michel in Normandy - A medieval abbey perched on a rocky island, Mont Saint-Michel is a unique and picturesque site that attracts visitors from around the world.
#
# 6. Château de Chambord in the Loire Valley - A grand Renaissance-style château known for its distinctive double helix staircase and sprawling grounds.
#
# These landmarks showcase the rich history, architecture, and cultural heritage of France.
# --------------------------------------------------
# User: How is the cuisine different from other countries?
# Assistant: French cuisine is known for its emphasis on high-quality, fresh ingredients and precise culinary techniques. It is often characterized by rich, creamy sauces, butter, and herbs. French cuisine also places a strong emphasis on presentation and artful plating. The use of a wide variety of cheeses, bread, and pastries is also quintessentially French.
#
# French cuisine has had a significant influence on culinary traditions around the world, particularly in Western countries. Many classic cooking techniques and recipes have originated from French cuisine and have been adapted and incorporated into other culinary traditions.
#
# Overall, the distinctiveness of French cuisine lies in its emphasis on balance, precision, and attention to detail, making it a revered and beloved culinary tradition worldwide.
# --------------------------------------------------
# User: What is the best time of year to visit?
# Assistant: The best time to visit France largely depends on your preferences and what you want to experience during your trip. Here are some considerations for each season:
#
# 1. Spring (April to June): This is a popular time to visit as the weather is generally mild and pleasant. Spring in France brings blooming flowers, especially in parks and gardens. It's a great time for outdoor activities and exploring the countryside.
#
# 2. Summer (July to August): Summer is peak tourist season in France, with warm weather and longer days. This is a great time for outdoor festivals, beach vacations, and exploring cities. However, popular tourist destinations can be crowded during this time.
#
# 3. Fall (September to November): Fall is a beautiful time to visit France, with cooler temperatures and vibrant autumn colors. It's a good time for wine tasting, exploring the countryside, and enjoying fall harvest festivals.
#
# 4. Winter (December to February): Winter in France can be chilly, especially in northern regions. However, it's a great time to experience holiday markets, winter sports in the Alps, and cultural events in cities. You can also enjoy cozy evenings by the fireplace with some hearty French cuisine.
#
# Ultimately, the best time to visit France depends on your interests and what you want to experience during your trip. Each season offers unique experiences and attractions, so consider what you want to do and see before planning your visit.
# --------------------------------------------------

# %%
# Print final conversation for verification
print("\nFinal conversation:")
for message in conversation:
    print(f"{message['role'].capitalize()}: {message['content']}")
# Out:
# Final conversation:
# User: What is the capital of France?
# Assistant: The capital of France is Paris.
# User: How is the cuisine different from other countries?
# Assistant: French cuisine is known for its emphasis on high-quality, fresh ingredients and precise culinary techniques. It is often characterized by rich, creamy sauces, butter, and herbs. French cuisine also places a strong emphasis on presentation and artful plating. The use of a wide variety of cheeses, bread, and pastries is also quintessentially French.
#
# French cuisine has had a significant influence on culinary traditions around the world, particularly in Western countries. Many classic cooking techniques and recipes have originated from French cuisine and have been adapted and incorporated into other culinary traditions.
#
# Overall, the distinctiveness of French cuisine lies in its emphasis on balance, precision, and attention to detail, making it a revered and beloved culinary tradition worldwide.
# User: What is the best time of year to visit?
# Assistant: The best time to visit France largely depends on your preferences and what you want to experience during your trip. Here are some considerations for each season:
#
# 1. Spring (April to June): This is a popular time to visit as the weather is generally mild and pleasant. Spring in France brings blooming flowers, especially in parks and gardens. It's a great time for outdoor activities and exploring the countryside.
#
# 2. Summer (July to August): Summer is peak tourist season in France, with warm weather and longer days. This is a great time for outdoor festivals, beach vacations, and exploring cities. However, popular tourist destinations can be crowded during this time.
#
# 3. Fall (September to November): Fall is a beautiful time to visit France, with cooler temperatures and vibrant autumn colors. It's a good time for wine tasting, exploring the countryside, and enjoying fall harvest festivals.
#
# 4. Winter (December to February): Winter in France can be chilly, especially in northern regions. However, it's a great time to experience holiday markets, winter sports in the Alps, and cultural events in cities. You can also enjoy cozy evenings by the fireplace with some hearty French cuisine.
#
# Ultimately, the best time to visit France depends on your interests and what you want to experience during your trip. Each season offers unique experiences and attractions, so consider what you want to do and see before planning your visit.

# %% [markdown]
# ## Other NLP applications with the LLM
# -------------------------------------

# %% [markdown]
# #### Language Translation
# The OpenAI API also supports language translation.
#
# You can provide a piece of text in one language and ask the API to translate it into another language. Here’s an example:

# %%
system
# Out:
# []

# %%
completion = client.chat.completions.create (
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": "You are a poetic assistant, skilled in explaining complex programming concepts with creative flair."},
    {"role": "user",   "content": "Compose a poem that explains the \
                                   concept of recursion in programming, \
                                   in max 50 words"}
  ]
)

# %%
# text = "Hello, how are you?"

# response = openai.Completion.create(
#   engine = "text-davinci-003",
#   prompt = f"Translate from English to Hindi: {text}",
#   max_tokens=50
# )

# translation = response.choices[0].text.strip()
# print(translation)

# %% [markdown]
# #### Sentiment Analysis
# You can also use the OpenAI API for sentiment analysis. Given a piece of text, the API will tell you whether it has a positive or negative sentiment. Here’s an example:

# %%
text = "I love horror movies!"

response = client.chat.completions.create(
                  model="gpt-3.5-turbo",
                  messages=[
                    {"role": "system", "content": "You are a NLP expert"},
                    {"role": "user",   "content": f"Perform sentiment analysis of given text : {text}"
                    
                    }
                  ]
)

sentiment = response.choices[0].message.content.replace("\n", " ")
print(sentiment)
# Out:
# The sentiment of the given text "I love horror movies!" is positive. The words "love" indicates a strong positive sentiment towards horror movies.

# %% [markdown]
# #### Question-Answering
# The OpenAI API also supports question-answering. You can provide a context and a question, and the API will return an answer based on that context. Here’s an example:

# %%
context  = "Albert Einstein was a German-born theoretical physicist who developed the \
theory of relativity."

question = "Where was Albert Einstein born?"

response = client.chat.completions.create(
                  model="gpt-3.5-turbo",
                  messages=[
                    {"role": "system", "content": "You are a NLP expert"},
                    {"role": "user",   "content": f"Question answering:\nContext: {context}\nQuestion: {question}"
                    
                    }
                  ],
                 temperature= 0.001
)

answer = response.choices[0].message.content.replace("\n", " ")
print(answer)
# Out:
# Albert Einstein was born in Ulm, in the Kingdom of Württemberg in the German Empire on March 14, 1879.

# %%
context = '''positive for TTF 1, and napsin A, 
suggestive of lung adenocarcinoma. Molecular testing was performed, that did not reveal actionable
therapeutically targetable mutations. She underwent chemotherapy therapy, 
to this paraspinal mass, administered concurrently with carboplatin and paclitaxel. 
She was then treated with 4 cycles of systemic therapy with carboplatin, and pemetrexed, and then.'''

question = '''

Did the patient undergo radiation therapy or any similar therapies in recent past or in the past? 

Your answer should be either 'Yes' or 'NO' or "Not sure' ONLY, With a label prefix "Answer",
Followed by reasoning in 50 words with a label prefix "Explanation",
followed by confidence score & scale, with a label prefix "Confidence Score/ label : "

'''

response = client.chat.completions.create(
                  model="gpt-4o",
                  messages=[
                    {"role": "system", "content": "You are a NLP expert"},
                    {"role": "user",   "content": f"Question answering:\nContext: {context}\nQuestion: {question}",
                    
                    }
                  ],
                 temperature= 0.001
)

answer = response.choices[0].message.content.replace("\n", " ")
print(answer)
# Out:
# Answer: Not sure  Explanation: The context mentions chemotherapy with carboplatin and paclitaxel, but it does not explicitly state whether radiation therapy or similar therapies were administered. Without specific mention of radiation therapy, it is unclear if the patient underwent such treatment.  Confidence Score/label: 70% (Moderate confidence due to lack of explicit information)
