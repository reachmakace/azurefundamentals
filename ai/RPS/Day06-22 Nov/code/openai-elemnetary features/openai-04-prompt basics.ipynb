# %% [markdown]
# -------------------------
# #### Prompt Engg
#
# - basic example using `chat completions`
# - code contains exmaples from 0.28 and later 1.35/1.45 versions of API
# --------------------

# %%
#pip install openai==1.45

# %%
import os
import openai

# %%
openai.__version__
# Out:
# '2.7.2'

# %% [markdown]
# #### models in openAI
# ------------------------------------
#
# OpenAI provides a variety of models, each suited for different use cases, ranging from text generation, code generation, to specific tasks like question answering, summarization, and more.
#
# | Model Type               | Description                                                                                       | Model ID               | Variants/Use Cases                                           |
# |--------------------------|---------------------------------------------------------------------------------------------------|------------------------|-------------------------------------------------------------|
# | **GPT-4 Models**         | The most advanced language model, designed for a wide range of tasks, including text completion and complex reasoning. | `gpt-4`                | Variants: `gpt-4`, `gpt-4-32k` (larger context window)     |
# | **GPT-3.5 Models**       | A slightly earlier version of the GPT-4 model, used for efficient and high-quality completions across various tasks. | `gpt-3.5-turbo`        |                                                             |
# | **Codex Models**         | Specialized for code generation tasks, including programming in multiple languages.              | `code-davinci-002`, `code-cushman-001` | Use cases: Autocomplete for code, bug fixes, code explanations. |
# | **Text-Davinci Models**  | One of the most capable models for text generation, document completion, and more.              | `text-davinci-003`     | Use cases: Writing, summarization, text generation.         |

# %% [markdown]
# ##### Key Properties of Models:
# - **Token Limit**: Defines how much input and output the model can handle in a single request. For example:
#   - GPT-4 has a context length limit of 8,192 tokens, and `gpt-4-32k` can handle up to 32,768 tokens.
# - **Training Data**: The models are trained on a mixture of publicly available and licensed datasets but have a knowledge cutoff (e.g., GPT-4 has a cutoff in September 2021).
#
# Each model has a balance of capability, efficiency, and cost, and you can select the right one depending on the task you need to perform.

# %% [markdown]
# #### Endpoints
# -----------------------------
#
# - OpenAI provides several API endpoints that enable developers to interact with their models for various tasks such as `text generation`, `conversation`, `code completion`, `embedding generation`, and more.
#
# - Each endpoint serves a different purpose and can be accessed via HTTP requests.

# %% [markdown]
# #### 1. Text Completion (Legacy) Endpoint (`/v1/completions`)
#
# While still technically supported, the Completions endpoint is considered legacy. It directly generates text from a prompt without the conversation history format used in the Chat endpoint.
#
# **API Endpoint**:
# POST https://api.openai.com/v1/completions
#
# **Usage**:
# Legacy usage for tasks like document completion, content generation, and summarization.
#
# **Key Parameters**:
# - `model`: Specifies the model (e.g., `text-davinci-003`).
# - `prompt`: The input text to be completed.
# - `max_tokens`: The number of tokens to generate.
# - `temperature`: Controls randomness in the output (higher value = more creative, lower = more deterministic).

# %%
import openai

# %%
# for older 0.28 API
# Make a request to the Completions Endpoint
# response = openai.Completion.create(
#   model       = "gpt-3.5-turbo",                                # Specify the model you want to use
#   prompt      = "Once upon a time, there was a wise owl that",  # Input prompt
#   max_tokens  = 50,                                             # The maximum number of tokens to generate
#   temperature = 0.7,                                            # Controls randomness (0.7 = moderate creativity)
#   n           = 1,                                              # The number of completions to generate
#   stop        = None                                            # Optional stop sequence
# )

# %%
# Print the generated completion
# print(response['choices'][0]['message']['content'])

# %%
# def get_completion(prompt, model="gpt-3.5-turbo"):
#     messages = [{"role": "user", "content": prompt}]
#     response = openai.ChatCompletion.create(                            # older 0.28 
#         model      = model,
#         messages   = messages,
#         temperature= 0, # this is the degree of randomness of the model's output
#     )
#     return response.choices[0].message["content"]

# %%
# prompt = """
# Translate the following English sentence to French:

# 'Hello, world!'
# """

# %%
# response = get_completion(prompt)
# print(response)

# %% [markdown]
# #### 2. Chat Completion Endpoint (/v1/chat/completions)
#
# **Purpose**: Designed for GPT models (GPT-3.5, GPT-4) to handle conversation-like inputs, but can be used for tasks similar to text generation.
#
# **API Endpoint**: POST https://api.openai.com/v1/chat/completions

# %% [markdown]
# **Usage**: It’s the recommended endpoint for most tasks, including text completion, Q&A, summarization, etc., by providing a chat history as input.
#
# **Key Parameters**:
#
# - **model**: Specifies the model to be used (e.g., gpt-4 or gpt-3.5-turbo).
# - **messages**: A list of messages, where each message contains:
#   - **role**: Either "system", "user", or "assistant".
#   - **content**: The text for the message.
# - **max_tokens**: Controls how many tokens to generate.
# - **temperature**: Controls randomness in the output (higher value = more random).

# %%
from openai import OpenAI

# %%
# openai_key = '' # michael

# %%
client = OpenAI(
    # defaults to os.environ.get("OPENAI_API_KEY")
    # api_key = openai_key
)

# %%
# Make a request to the Chat Completion Endpoint
response = client.chat.completions.create(
    model   ="gpt-3.5-turbo",  # Specify the model
    messages=[
        {"role": "user", "content": "Can you summarize the key parameters for the Chat Completion Endpoint?"}
    ],
    max_tokens = 100,
    # 0 = Same response each time and 1 = More randomness
    temperature= 0.7
)

# %%
print(response.choices[0].message.content)
# Out:
# Sure! The key parameters for the Chat Completion Endpoint typically include:
#
# 1. Chat ID: The unique identifier for the chat session.
# 2. Conversation ID: The identifier for the ongoing conversation within the chat session.
# 3. Completion Status: Indicates whether the chat session has been successfully completed or not.
# 4. Completion Message: Optional message detailing the completion status.
# 5. Timestamp: The date and time when the chat session was completed.
# 6. User ID: The identifier for the user participating in the chat

# %% [markdown]
# #### Messages

# %% [markdown]
# In OpenAI's API for language models, messages are the fundamental building blocks of prompts.
#
# Each message typically consists of two main components: the `role` of the sender and the `content` of the message.
#
# | **Role**   | **Description**                                                                                                                                                 | **Example**                                                                                                                  |
# |------------|-----------------------------------------------------------------------------------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------------------------------------|
# | User       | Represents the end user or the application initiating the conversation. Sends input messages, asking questions or providing information for the model's response. | If a user asks, "What is machine learning?", the message is sent with the role of "user".                                  |
# | Assistant  | Represents the AI model's responses to the user’s queries. Generates replies based on the context and content of previous messages, aiming to be helpful and informative. | After the user asks about machine learning, the assistant might respond, "Machine learning is a subset of artificial intelligence that focuses on building systems that learn from data." |
# | System     | Provides initial instructions or context to the assistant to guide its behavior throughout the interaction. Typically used to set the tone, rules, or constraints of the assistant’s responses. | A system message might state, "You are a friendly and informative assistant."                                              |

# %%
[
  {"role": "system",    "content": "You are a knowledgeable assistant in medical domain"},
  {"role": "user",      "content": "Can you tell me about neural networks?"},
  {"role": "assistant", "content": "Neural networks are a series of algorithms that mimic \
                                    the operations of a human brain to recognize relationships in a set of data."}
]
# Out:
# [{'role': 'system',
#   'content': 'You are a knowledgeable assistant in medical domain'},
#  {'role': 'user', 'content': 'Can you tell me about neural networks?'},
#  {'role': 'assistant',
#   'content': 'Neural networks are a series of algorithms that mimic                                     the operations of a human brain to recognize relationships in a set of data.'}]

# %%
client = openai.OpenAI(
    #api_key=openai_api_key
)

# %% [markdown]
# Example

# %%
completion = client.chat.completions.create (
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": "You are a poetic assistant, skilled in explaining complex programming concepts \
                                   with creative flair."},
    {"role": "user",   "content": "Compose a poem that explains the concept of recursion in programming, \
                                   in max 50 words"}
  ]
)

# %% [markdown]
# type(completion)

# %%
completion
# Out:
# ChatCompletion(id='chatcmpl-CeedgTz6HMdMJjQUp5BoFLD345EO4', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='In the realm of code, recursion sings,\nA dance of functions, nesting rings,\nA call to self, repeating flow,\nTill base case breaks the looping show.\nCircular echoes, patterns divine,\nInfinite beauty, in every line.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1763805372, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=48, prompt_tokens=46, total_tokens=94, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
def show_result(response):
    print(response.choices[0].message.content)
    return response.choices[0].message.content

# %%
res= show_result(completion)
# Out:
# In the realm of code, recursion sings,
# A dance of functions, nesting rings,
# A call to self, repeating flow,
# Till base case breaks the looping show.
# Circular echoes, patterns divine,
# Infinite beauty, in every line.

# %% [markdown]
# #### Deciphering the completion response object

# %%
import json
from pprint import pprint

# %%
# Pretty print the response using pprint
pprint(response.to_dict())
# Out:
# {'choices': [{'finish_reason': 'length',
#               'index': 0,
#               'logprobs': None,
#               'message': {'annotations': [],
#                           'content': 'Sure! The key parameters for the Chat '
#                                      'Completion Endpoint typically include:\n'
#                                      '\n'
#                                      '1. Chat ID: The unique identifier for '
#                                      'the chat session.\n'
#                                      '2. Conversation ID: The identifier for '
#                                      'the ongoing conversation within the chat '
#                                      'session.\n'
#                                      '3. Completion Status: Indicates whether '
#                                      'the chat session has been successfully '
#                                      'completed or not.\n'
#                                      '4. Completion Message: Optional message '
#                                      'detailing the completion status.\n'
#                                      '5. Timestamp: The date and time when the '
#                                      'chat session was completed.\n'
#                                      '6. User ID: The identifier for the user '
#                                      'participating in the chat',
#                           'refusal': None,
#                           'role': 'assistant'}}],
#  'created': 1763804945,
#  'id': 'chatcmpl-CeeWnmeldzMaibec4SXOTug6pfMUE',
#  'model': 'gpt-3.5-turbo-0125',
#  'object': 'chat.completion',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'usage': {'completion_tokens': 100,
#            'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                          'audio_tokens': 0,
#                                          'reasoning_tokens': 0,
#                                          'rejected_prediction_tokens': 0},
#            'prompt_tokens': 19,
#            'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0},
#            'total_tokens': 119}}

# %%
# Serialize to JSON and print
json_output = json.dumps(response.to_dict(), indent=4)
print(json_output)
# Out:
# {
#     "id": "chatcmpl-CeeWnmeldzMaibec4SXOTug6pfMUE",
#     "choices": [
#         {
#             "finish_reason": "length",
#             "index": 0,
#             "logprobs": null,
#             "message": {
#                 "content": "Sure! The key parameters for the Chat Completion Endpoint typically include:\n\n1. Chat ID: The unique identifier for the chat session.\n2. Conversation ID: The identifier for the ongoing conversation within the chat session.\n3. Completion Status: Indicates whether the chat session has been successfully completed or not.\n4. Completion Message: Optional message detailing the completion status.\n5. Timestamp: The date and time when the chat session was completed.\n6. User ID: The identifier for the user participating in the chat",
#                 "refusal": null,
#                 "role": "assistant",
#                 "annotations": []
#             }
#         }
#     ],
#     "created": 1763804945,
#     "model": "gpt-3.5-turbo-0125",
#     "object": "chat.completion",
#     "service_tier": "default",
#     "system_fingerprint": null,
#     "usage": {
#         "completion_tokens": 100,
#         "prompt_tokens": 19,
#         "total_tokens": 119,
#         "completion_tokens_details": {
#             "accepted_prediction_tokens": 0,
#             "audio_tokens": 0,
#             "reasoning_tokens": 0,
#             "rejected_prediction_tokens": 0
#         },
#         "prompt_tokens_details": {
#             "audio_tokens": 0,
#             "cached_tokens": 0
#         }
#     }
# }

# %% [markdown]
# #### Attributes of ChatCompletion
#
# | Attribute          | Description                                                                                  |
# |--------------------|----------------------------------------------------------------------------------------------|
# | **id**             | A unique identifier for the completion request (e.g., `'chatcmpl-ABc5tNfn75ylhDfYoCrEBNlqk6xqO'`). |
# | **choices**        | A list of `Choice` objects representing the different responses generated by the model. In this case, there is one choice. |
# | **created**        | A timestamp indicating when the completion was created (e.g., `1727331405`).               |
# | **model**          | The model used to generate the completion (e.g., `'gpt-3.5-turbo-0125'`).                   |
# | **object**         | The type of object, which indicates it's a `chat.completion`.                               |
# | **usage**          | An object that details the token usage for the request and response, including:            |
# |                    | - **completion_tokens**: Number of tokens used in the completion (e.g., `45`).              |
# |                    | - **prompt_tokens**: Number of tokens used in the input prompt (e.g., `46`).               |
# |                    | - **total_tokens**: Total number of tokens used (e.g., `91`).                              |

# %% [markdown]
# **Choices**
#
# | Attribute               | Description                                                                                              |
# |-------------------------|----------------------------------------------------------------------------------------------------------|
# | **finish_reason**        | The reason the completion finished (e.g., `'stop'`).                                                     |
# | **index**                | The index of the choice in the list.                                                                     |
# | **logprobs**             | Any associated log probabilities (in this case, it's `None`).                                            |
# | **message**              | An instance of `ChatCompletionMessage` that contains:                                                    |
# | - **content**            | The actual text generated by the model (e.g., a poem about recursion).                                   |
# | - **role**               | The role of the entity that generated the message (e.g., `'assistant'`).                                 |
# | - **function_call**      | Information if the message included a function call (in this case, it's `None`).                         |
# | - **tool_calls**         | Information if there were any tool calls (also `None` in this case).                                     |

# %% [markdown]
# #### Exercise - 01
#
# - (extract pieces of info from the completion response)

# %%
response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user",   "content": "Who won the world series in 2020?"},
    ]
)

# %%
res = show_result(response)
# Out:
# The Los Angeles Dodgers won the World Series in 2020, defeating the Tampa Bay Rays.

# %% [markdown]
# Qs : Extract the model name from the response object.

# %%
# Expected solution
model_name = response.to_dict()['model']
print("Model used:", model_name)
# Out:
# Model used: gpt-3.5-turbo-0125

# %% [markdown]
# Qs : Extract the content of the assistant’s reply from the response object.

# %%
# Expected solution
assistant_reply = response.to_dict()['choices'][0]['message']['content']
print("Assistant's reply:", assistant_reply)
# Out:
# Assistant's reply: The Los Angeles Dodgers won the World Series in 2020, defeating the Tampa Bay Rays.

# %% [markdown]
# let us change the prompt to add a few more years ...

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user",   "content": "Who won the world series in 2020, 2021, 2022, 2023 ?"},
    ]
)

# %% [markdown]
# Qs : Create a dictionary of World Series winners by year from the assistant’s reply.

# %%
# Example solution
winners_by_year = response.to_dict()['choices'][0]['message']['content']
print(winners_by_year)
# Out:
# The winners of the World Series for the years you mentioned are as follows:
#
# - **2020**: Los Angeles Dodgers
# - **2021**: Atlanta Braves
# - **2022**: Houston Astros
# - **2023**: Texas Rangers
#
# If you have any more questions, feel free to ask!

# %% [markdown]
# Get the output in a dictionary format, year : winner name

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user",   "content": "Who won the Cricket world cup in 2020, 2021, 2022, 2023, 2026 ? \
                                       Provide the answer in a dictionary format as below \
                                       year : winner name \
                                       "},
    ]
)

# %%
# Example solution
winners_by_year = response.to_dict()['choices'][0]['message']['content']
print(winners_by_year)
# Out:
# Here is the information you requested in dictionary format:
#
# ```python
# {
#     2020: None,  # No Men's Cricket World Cup was held in 2020.
#     2021: "Australia",  # ICC Men's T20 World Cup
#     2022: None,  # No Men's Cricket World Cup was held in 2022.
#     2023: "India",  # ICC Men's Cricket World Cup
#     2026: None  # The next Men's Cricket World Cup after 2023 is scheduled for 2027.
# }
# ```
#
# Please note:
# - The 2020 ICC Men's T20 World Cup was scheduled to take place but was canceled due to the COVID-19 pandemic.
# - The 2022 ICC Men's T20 World Cup was held, but no other major World Cup events took place in those specific years. The next Men's World Cup will occur in 2027.

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user",   "content": '''Who won the Cricket world cup in 2020, 2021, 2022, 2023 ? \
                                       Provide the answer in a dictionary format as below \
                                       {
                                           year : winner name 
                                       }
                                       without any extra text
                                       \
                                       '''},
    ]
)

# %% [markdown]
# Qs : load the output in dataframe format

# %% [markdown]
# | Year | Winner                |
# |------|-----------------------|
# | 2020 | Los Angeles Dodgers   |
# | 2021 | Atlanta Braves        |
# | 2022 | Houston Astros        |
# | 2023 | Texas Rangers         |

# %%
# Example solution
winners_by_year = response.to_dict()['choices'][0]['message']['content']
winners_by_year
# Out:
# '{\n  2020: "No tournament",\n  2021: "Australia",\n  2022: "England",\n  2023: "India"\n}'

# %%
import pandas as pd
import ast

# %%
# Convert the string representation of the dictionary to an actual dictionary
world_series_dict = ast.literal_eval(winners_by_year)

# %%
world_series_dict
# Out:
# {2020: 'No tournament', 2021: 'Australia', 2022: 'England', 2023: 'India'}

# %%
# Load the dictionary into a pandas DataFrame
df = pd.DataFrame(list(world_series_dict.items()), columns=['Year', 'Winner'])
df
# Out:
#    Year         Winner
# 0  2020  No tournament
# 1  2021      Australia
# 2  2022        England
# 3  2023          India

# %% [markdown]
# Qs : Extract only the winner names from the dictionary and store them in a list.

# %%
# Convert to dictionary
world_series_dict = ast.literal_eval(winners_by_year)

# %%
# Extract winners
winners = list(world_series_dict.values())
winners
# Out:
# ['No tournament', 'Australia', 'England', 'India']

# %% [markdown]
# Qs : Convert the dictionary into a list of tuples with (Year, Winner).

# %%
# Convert to dictionary
world_series_dict = ast.literal_eval(winners_by_year)

# %%
# Convert to list of tuples
year_winner_tuples = list(world_series_dict.items())
year_winner_tuples
# Out:
# [(2020, 'No tournament'),
#  (2021, 'Australia'),
#  (2022, 'England'),
#  (2023, 'India')]

# %% [markdown]
# Qs : Write a function that checks if a given team won the World Series in a specified year.

# %%
def did_team_win(year, team):
    return world_series_dict.get(year) == team

# %%
# Example usage:
print(did_team_win(2020, "India"))  # Expected: True
print(did_team_win(2022, "England"))  # Expected: False
# Out:
# False
# True

# %% [markdown]
# Qs : Find the most recent World Series winner

# %%
# Find the most recent year
most_recent_year = max(world_series_dict.keys())

# %%
# Get the winner of the most recent year
most_recent_winner = world_series_dict[most_recent_year]

# Print the most recent winner
print(f"The most recent winner is {most_recent_winner} in {most_recent_year}.")
# Out:
# The most recent winner is India in 2023.

# %% [markdown]
# #### Finish Reason Summary
#
# | Finish Reason      | Description                                                                                                            | Example                             |
# |--------------------|------------------------------------------------------------------------------------------------------------------------|-------------------------------------|
# | "stop"             | The model completed its response naturally, reaching a logical stopping point like the end of a sentence or thought.  | "finish_reason": "stop"            |
# | "length"           | The response was cut off because the model reached the maximum number of tokens allowed in the API request.            | "finish_reason": "length"          |
# | "content_filter"   | The response was stopped because it triggered the safety filter, likely due to generating inappropriate or unsafe content. | "finish_reason": "content_filter"  |
# | null               | The completion ended for an unknown or unspecified reason, or there was no particular reason captured (rare, edge case scenario). | "finish_reason": null               |

# %% [markdown]
# #### Index Attribute Summary
#
# | Index | Description                                                                                      | Example                 |
# |-------|--------------------------------------------------------------------------------------------------|-------------------------|
# | 0     | The index of the choice in the list of choices returned by the model. It typically starts at 0. | "index": 0              |
# | 1     | Indicates the second choice in the list, if multiple choices are generated.                      | "index": 1              |
# | 2     | Represents the third choice in the list of generated responses, if applicable.                   | "index": 2              |
# | ...   | Continues incrementing for additional choices returned, based on the number of choices.         | "index": n (where n is the choice number) |

# %% [markdown]
# #### Message Attribute Summary
#
# | Attribute         | Description                                                                                             | Example                                                              |
# |-------------------|---------------------------------------------------------------------------------------------------------|----------------------------------------------------------------------|
# | content           | The actual text generated by the model, representing the response.                                     | "content": "This is the generated text."                            |
# | role              | Indicates the role of the entity that generated the message, typically "assistant" for model responses.| "role": "assistant"                                                 |
# | function_call     | Contains information about any function calls included in the message, if applicable (otherwise None).| "function_call": None                                               |
# | tool_calls        | Provides information about any tool calls made during the response generation (usually None).          | "tool_calls": None                                                  |

# %% [markdown]
# #### Reasoning abilities

# %%
context = '''
during the start of the training program, the learners were asked if they wished certain AI topics or lessons
they would like the instructor to provide a quick recap or brush up and illustrations. Based of their feedback
the instructor captured list of topics for the recap. The agreed assumption was that the learners are familiar with
the topics but needed a quick refresher on them. The instructor provided walk thru on each of the topics with examples and illustration 
with python codes and gave them time of 5 mins on each topic if they had any qs or difficulties. During the entire 4 sessions the learners
do not complaing about understanding the concepts, code, examples even after being polled explicitly for their repsonse.
But a couple of them provide feedback at the end of the week to their manager, instead. leaving the instructor completely unaware.
'''

feedback = '''
the trainer’s pace was slower than expected, and it seemed like he was copying code from his notebook 
without providing sufficient explanations on the "what" and "why" behind the actions. 
need for more in-depth explanations and context.
'''

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are a helpful assistant with abilities to interpret learners' feedback."},
        {"role": "user", "content": f"Based on the {context}, assess if there are contradictions in the {feedback}. \
        Provide a clear explanation of your understanding of the feedback \
        Provide areas where learners could have helped the trainer in the recap sessions"}
    ],
    temperature=1.0
)

# %%
print(response.to_dict()['choices'][0]['message']['content'])
# Out:
# The feedback indicates that while the learners were generally satisfied with the sessions in terms of understanding the content, there was a disconnect between their actual experience and what they communicated to the instructor. Here’s a breakdown of the contradictions and insights based on the feedback:
#
# ### Understanding of the Feedback:
# 1. **Perception of Understanding**: During the sessions, learners did not express any confusion or problems in understanding the topics, which led the instructor to believe that the recap was effective. The instructor provided opportunities for questions, and the learners either felt comfortable or were hesitant to voice any issues in the moment.
#
# 2. **Contradictory Feedback**: Despite not expressing difficulties during the sessions, some learners later communicated to their manager that the trainer’s pace was slower than expected and that they wanted more in-depth explanations. This shows a gap in communication, wherein learners did not bring up their concerns in real-time, leading to the instructor remaining unaware of their needs.
#
# 3. **Desire for Context**: The learners noted that the trainer appeared to be copying code and did not sufficiently explain the underlying concepts (the "what" and "why"). The lack of context might have contributed to the perception that the sessions were slower, as the learners may have felt they were just watching code being executed rather than understanding it.
#
# ### Areas Where Learners Could Have Helped the Trainer:
# 1. **Active Engagement**: Learners could have actively engaged during each session by asking questions if they felt unclear about certain topics. Providing specific examples or questions about areas they found confusing or lacked contextual information would have helped the instructor adjust the pace or depth of explanations.
#
# 2. **Feedback During Sessions**: Encouraging an open feedback culture where learners feel comfortable sharing their thoughts during the sessions could have provided immediate insights into their understanding and comfort levels. This could involve using anonymous polls or a feedback tool that allows learners to express their feelings in real-time.
#
# 3. **Clarifying Expectations**: Early in the program, learners could clarify their expectations regarding the depth of content required in discussions. If they knew they wanted more than a recap, sharing that expectation explicitly would help the instructor tailor the lessons better.
#
# 4. **Providing Constructive Feedback**: Instead of waiting until the end of the course or providing feedback to a manager, the learners could directly tell the instructor what specific areas they felt needed deeper explanation or illustration. This direct line of communication would facilitate a more responsive learning environment.
#
# 5. **Utilizing Breaks for Discussion**: Learners could have used the 5 minutes allocated for questions to express concerns or suggest more details they felt were needed on specific topics. This would give immediate feedback about their understanding and what they were looking for.
#
# Overall, open and honest communication within the learning environment is crucial. This instance underscores the importance of creating a culture where learners feel they can express their needs in real-time.

# %% [raw]
# Based on the feedback provided, there are several key points to consider regarding the learners' experience during the training program:
#
# ### Understanding of the Feedback
#
# 1. **Initial Assumption vs. Actual Experience**: The instructor assumed that learners were familiar with the topics and only needed a quick refresher. However, the feedback suggests that while learners did not express difficulties during the sessions, they may not have fully understood the material due to a lack of depth in explanations.
#
# 2. **Pace of Instruction**: The feedback indicates that the trainer's pace was slower than expected, which could imply that learners felt the sessions were dragging or not engaging enough. This could lead to frustration, especially if they were looking for a more dynamic or interactive learning experience.
#
# 3. **Code Explanation**: The comment about the instructor copying code from his notebook without sufficient explanations highlights a disconnect between the learners' expectations and the instructor's delivery. Learners may have wanted more context about the code—specifically, the rationale behind certain coding choices and how they relate to the concepts being taught.
#
# 4. **Feedback Mechanism**: The fact that learners chose to provide feedback to their manager instead of directly to the instructor suggests a lack of open communication. This could indicate that learners did not feel comfortable voicing their concerns in real-time or that they did not believe their feedback would lead to changes.
#
# ### Areas Where Learners Could Have Helped the Trainer
#
# 1. **Real-Time Feedback**: Learners could have been encouraged to provide immediate feedback during the sessions. This could have been facilitated through anonymous polls or feedback forms after each topic, allowing the instructor to adjust the pace or depth of explanations as needed.
#
# 2. **Clarifying Expectations**: At the beginning of the training, learners could have articulated their expectations more clearly. If they were looking for deeper explanations or more context, expressing this upfront could have guided the instructor's approach.
#
# 3. **Asking Questions**: While the instructor provided time for questions, learners could have been more proactive in asking for clarification on specific points where they felt explanations were lacking. This would have helped the instructor identify areas that needed more attention.
#
# 4. **Providing Constructive Feedback**: Instead of waiting until the end of the week to provide feedback to their manager, learners could have shared their thoughts directly with the instructor. Constructive feedback during the sessions could have allowed the instructor to make adjustments in real-time.
#
# 5. **Engagement in Discussions**: Learners could have engaged more in discussions or group activities during the recap sessions. This could have fostered a more interactive environment where learners could share their understanding and clarify doubts collectively.
#
# In summary, while the instructor aimed to provide a recap based on the assumption of prior knowledge, the feedback indicates that learners may have needed more in-depth explanations and context. Encouraging open communication and real-time feedback could have enhanced the learning experience for everyone involved.

# %% [markdown]
# ## Useful applications of messaging structure
# ------------------------------------

# %%
# Initialize the conversation with a system message
conversation = [
    {"role": "system", "content": "You are a helpful assistant."}
]

# %%
def send_message(conversation):
    # Send the conversation to the OpenAI API and get a response
    
    response = client.chat.completions.create(
        model    = "gpt-3.5-turbo",
        messages = conversation
    )
    return response.to_dict()['choices'][0]['message']['content']

# %%
# Add user messages incrementally
user_inputs = [
    "What is the capital of France?",
    "Can you tell me more about its culture?",
    "What are some famous landmarks there?",
    "How is the cuisine different from other countries?",
    "What is the best time of year to visit?"
]

# %%
# Iterate through user inputs
for user_input in user_inputs:
    conversation.append({"role": "user", "content": user_input})
    
    # Get assistant's response
    assistant_response = send_message(conversation)
    
    conversation.append({"role": "assistant", "content": assistant_response})
    
    # Print the latest response
    print("User:", user_input)
    print("Assistant:", assistant_response)
    print("-" * 50)  # Separator for clarity
# Out:
# User: What is the capital of France?
# Assistant: The capital of France is Paris.
# --------------------------------------------------
# User: Can you tell me more about its culture?
# Assistant: Of course! French culture is known for its rich history, art, literature, cuisine, and fashion. French cuisine is world-renowned, with dishes like baguettes, croissants, cheese, wine, and pastries. The arts have also played a significant role in French culture, with famous painters such as Claude Monet and Henri Matisse, as well as writers like Victor Hugo and Gustave Flaubert.
#
# France has a long history of fashion and is considered a global hub for fashion design, with Paris being one of the fashion capitals of the world. French cinema is also highly regarded, with the Cannes Film Festival being one of the most prestigious film festivals in the world.
#
# The French take pride in their language and are known for their love of literature and philosophy. The country is also home to numerous landmarks and monuments, such as the Eiffel Tower, Louvre Museum, Notre-Dame Cathedral, and Palace of Versailles, which are all important symbols of French culture and history.
# --------------------------------------------------
# User: What are some famous landmarks there?
# Assistant: Some of the most famous landmarks in France include:
#
# 1. Eiffel Tower - Located in Paris, the Eiffel Tower is one of the most iconic structures in the world and a symbol of France.
#
# 2. Louvre Museum - Also in Paris, the Louvre is one of the largest and most visited art museums in the world, with a collection that includes the famous Mona Lisa.
#
# 3. Notre-Dame Cathedral - Situated in Paris, Notre-Dame Cathedral is a stunning example of French Gothic architecture and a UNESCO World Heritage Site.
#
# 4. Palace of Versailles - Located near Paris, the Palace of Versailles is a magnificent royal residence that served as the seat of political power in France for centuries.
#
# 5. Mont Saint-Michel - This picturesque island commune in Normandy is topped by a medieval abbey and is a popular tourist destination.
#
# 6. Château de Chambord - A stunning Renaissance château in the Loire Valley known for its distinctive French architecture.
#
# 7. Arc de Triomphe - Another iconic monument in Paris, the Arc de Triomphe honors those who fought and died for France in the French Revolutionary and Napoleonic Wars.
#
# These are just a few of the many incredible landmarks that can be found throughout France, each with its own unique history and significance.
# --------------------------------------------------
# User: How is the cuisine different from other countries?
# Assistant: French cuisine is highly regarded worldwide for its focus on quality ingredients, meticulous preparation, and emphasis on flavor and presentation. Some key characteristics that set French cuisine apart from other countries include:
#
# 1. Culinary traditions: France has a long culinary tradition dating back centuries, with each region having its own specialties and local ingredients. French cooking techniques are refined and precise, with an emphasis on classic dishes and recipes passed down through generations.
#
# 2. Use of fresh, high-quality ingredients: French cuisine places a strong emphasis on using fresh, seasonal ingredients to create dishes that highlight the natural flavors of the ingredients. French chefs often source their ingredients locally and take pride in the quality of the products they use.
#
# 3. Sauces and complex flavors: French cuisine is known for its rich and flavorful sauces, such as béchamel, hollandaise, and velouté, which are used to enhance and complement dishes. The French also have a strong tradition of using herbs, spices, and aromatic ingredients to create complex and sophisticated flavors.
#
# 4. Bread and pastries: France is famous for its bread, with baguettes and croissants being staples of French cuisine. Pastries and desserts are also an integral part of French culinary culture, with classics like crème brûlée, tarte Tatin, and macarons delighting food lovers around the world.
#
# Overall, French cuisine is characterized by its attention to detail, emphasis on quality ingredients, and a rich culinary history that has influenced gastronomy worldwide.
# --------------------------------------------------
# User: What is the best time of year to visit?
# Assistant: The best time to visit France depends on your preferences and what you want to experience during your trip. Here are some factors to consider:
#
# 1. Weather: The most popular time to visit France is during the spring (April to June) and fall (September to October) when the weather is mild, and there are fewer crowds. The summer months (July and August) can also be a good time to visit, but it can be hot and crowded, especially in popular tourist destinations like Paris and the French Riviera.
#
# 2. Events and festivals: France hosts numerous events and festivals throughout the year, including the Cannes Film Festival in May, the Tour de France in July, and Bastille Day celebrations on July 14th. If you want to experience these cultural events, plan your trip accordingly.
#
# 3. Seasonal activities: Depending on your interests, you may want to visit during a specific season to take part in seasonal activities. For example, the winter months (December to February) are great for skiing in the French Alps, while the spring is ideal for exploring the beautiful gardens in bloom.
#
# Ultimately, the best time to visit France is subjective and depends on your preferences, interests, and what you want to experience during your trip. No matter when you choose to visit, France has something to offer year-round, from its world-class cuisine and stunning landmarks to its rich cultural heritage.
# --------------------------------------------------

# %%
conversation
# Out:
# [{'role': 'system', 'content': 'You are a helpful assistant.'},
#  {'role': 'user', 'content': 'What is the capital of France?'},
#  {'role': 'assistant', 'content': 'The capital of France is Paris.'},
#  {'role': 'user', 'content': 'Can you tell me more about its culture?'},
#  {'role': 'assistant',
#   'content': 'Of course! French culture is known for its rich history, art, literature, cuisine, and fashion. French cuisine is world-renowned, with dishes like baguettes, croissants, cheese, wine, and pastries. The arts have also played a significant role in French culture, with famous painters such as Claude Monet and Henri Matisse, as well as writers like Victor Hugo and Gustave Flaubert.\n\nFrance has a long history of fashion and is considered a global hub for fashion design, with Paris being one of the fashion capitals of the world. French cinema is also highly regarded, with the Cannes Film Festival being one of the most prestigious film festivals in the world.\n\nThe French take pride in their language and are known for their love of literature and philosophy. The country is also home to numerous landmarks and monuments, such as the Eiffel Tower, Louvre Museum, Notre-Dame Cathedral, and Palace of Versailles, which are all important symbols of French culture and history.'},
#  {'role': 'user', 'content': 'What are some famous landmarks there?'},
#  {'role': 'assistant',
#   'content': 'Some of the most famous landmarks in France include:\n\n1. Eiffel Tower - Located in Paris, the Eiffel Tower is one of the most iconic structures in the world and a symbol of France.\n\n2. Louvre Museum - Also in Paris, the Louvre is one of the largest and most visited art museums in the world, with a collection that includes the famous Mona Lisa.\n\n3. Notre-Dame Cathedral - Situated in Paris, Notre-Dame Cathedral is a stunning example of French Gothic architecture and a UNESCO World Heritage Site.\n\n4. Palace of Versailles - Located near Paris, the Palace of Versailles is a magnificent royal residence that served as the seat of political power in France for centuries.\n\n5. Mont Saint-Michel - This picturesque island commune in Normandy is topped by a medieval abbey and is a popular tourist destination.\n\n6. Château de Chambord - A stunning Renaissance château in the Loire Valley known for its distinctive French architecture.\n\n7. Arc de Triomphe - Another iconic monument in Paris, the Arc de Triomphe honors those who fought and died for France in the French Revolutionary and Napoleonic Wars.\n\nThese are just a few of the many incredible landmarks that can be found throughout France, each with its own unique history and significance.'},
#  {'role': 'user',
#   'content': 'How is the cuisine different from other countries?'},
#  {'role': 'assistant',
#   'content': 'French cuisine is highly regarded worldwide for its focus on quality ingredients, meticulous preparation, and emphasis on flavor and presentation. Some key characteristics that set French cuisine apart from other countries include:\n\n1. Culinary traditions: France has a long culinary tradition dating back centuries, with each region having its own specialties and local ingredients. French cooking techniques are refined and precise, with an emphasis on classic dishes and recipes passed down through generations.\n\n2. Use of fresh, high-quality ingredients: French cuisine places a strong emphasis on using fresh, seasonal ingredients to create dishes that highlight the natural flavors of the ingredients. French chefs often source their ingredients locally and take pride in the quality of the products they use.\n\n3. Sauces and complex flavors: French cuisine is known for its rich and flavorful sauces, such as béchamel, hollandaise, and velouté, which are used to enhance and complement dishes. The French also have a strong tradition of using herbs, spices, and aromatic ingredients to create complex and sophisticated flavors.\n\n4. Bread and pastries: France is famous for its bread, with baguettes and croissants being staples of French cuisine. Pastries and desserts are also an integral part of French culinary culture, with classics like crème brûlée, tarte Tatin, and macarons delighting food lovers around the world.\n\nOverall, French cuisine is characterized by its attention to detail, emphasis on quality ingredients, and a rich culinary history that has influenced gastronomy worldwide.'},
#  {'role': 'user', 'content': 'What is the best time of year to visit?'},
#  {'role': 'assistant',
#   'content': 'The best time to visit France depends on your preferences and what you want to experience during your trip. Here are some factors to consider:\n\n1. Weather: The most popular time to visit France is during the spring (April to June) and fall (September to October) when the weather is mild, and there are fewer crowds. The summer months (July and August) can also be a good time to visit, but it can be hot and crowded, especially in popular tourist destinations like Paris and the French Riviera.\n\n2. Events and festivals: France hosts numerous events and festivals throughout the year, including the Cannes Film Festival in May, the Tour de France in July, and Bastille Day celebrations on July 14th. If you want to experience these cultural events, plan your trip accordingly.\n\n3. Seasonal activities: Depending on your interests, you may want to visit during a specific season to take part in seasonal activities. For example, the winter months (December to February) are great for skiing in the French Alps, while the spring is ideal for exploring the beautiful gardens in bloom.\n\nUltimately, the best time to visit France is subjective and depends on your preferences, interests, and what you want to experience during your trip. No matter when you choose to visit, France has something to offer year-round, from its world-class cuisine and stunning landmarks to its rich cultural heritage.'}]

# %%
len(conversation)
# Out:
# 11

# %% [markdown]
# **Strategies to Manage Conversation Length**

# %%
# Initialize the conversation with a system message
conversation = [
    {"role": "system", "content": "You are a helpful assistant."}
]

# %%
def send_message(conversation):
    # Send the conversation to the OpenAI API and get a response
    response = client.chat.completions.create(
        model    = "gpt-3.5-turbo",
        messages = conversation
    )
    return response.to_dict()['choices'][0]['message']['content']

# %%
# Add user messages incrementally
user_inputs = [
    "What is the capital of France?",
    "Can you tell me more about its culture?",
    "What are some famous landmarks there?",
    "How is the cuisine different from other countries?",
    "What is the best time of year to visit?"
]

# %%
# Set a limit for how many exchanges to keep
max_history_length = 6  # Total messages to keep (including system message)

# %%
# Flag to indicate if the initial question has been answered
initial_question_responded = False

# %%
# Iterate through user inputs
for user_input in user_inputs:
    conversation.append({"role": "user", "content": user_input})
    
    # Get assistant's response
    assistant_response = send_message(conversation)
    conversation.append({"role": "assistant", "content": assistant_response})
    
    # Print the latest response
    print("User:", user_input)
    print("Assistant:", assistant_response)
    print("-" * 50)  # Separator for clarity

    # Truncate the conversation to the most recent exchanges
    if len(conversation) > max_history_length:
        # Always keep the first question and its response
        if not initial_question_responded:
            # Keep the first user question and its response
            initial_question = conversation[1]  # User question
            initial_response = conversation[2]  # Assistant response
            # Retain them in the conversation
            conversation = [conversation[0], initial_question, initial_response]
            initial_question_responded = True
        else:
            # Keep only the last `max_history_length` messages
            conversation = conversation[-max_history_length:]
# Out:
# User: What is the capital of France?
# Assistant: The capital of France is Paris.
# --------------------------------------------------
# User: Can you tell me more about its culture?
# Assistant: Certainly! French culture is known for its rich history, art, cuisine, and literature. France is renowned for its fine wines and cheeses, as well as its culinary traditions. French art has made significant contributions to various fields, including painting, sculpture, architecture, and fashion.
#
# Literature also plays a significant role in French culture, with many famous writers and poets hailing from France. The country has a long history of producing influential philosophers, thinkers, and artists.
#
# Additionally, France is known for its vibrant music scene, with genres ranging from classical and opera to modern pop and electronic music. The French also have a strong tradition of cinema, with French films being celebrated worldwide for their creativity and artistic merit.
#
# Overall, French culture is characterized by a deep appreciation for beauty, creativity, and intellectual pursuits.
# --------------------------------------------------
# User: What are some famous landmarks there?
# Assistant: Some famous landmarks in France include:
#
# 1. Eiffel Tower in Paris: One of the most iconic structures in the world, the Eiffel Tower is a must-visit symbol of France.
#
# 2. Louvre Museum in Paris: One of the world's largest and most famous museums, the Louvre is home to thousands of works of art, including the renowned Mona Lisa.
#
# 3. Palace of Versailles near Paris: This grand palace was the principal royal residence of France from 1682 until the start of the French Revolution.
#
# 4. Mont Saint-Michel in Normandy: A picturesque island commune with a medieval abbey perched on top, Mont Saint-Michel is a UNESCO World Heritage Site.
#
# 5. Notre-Dame Cathedral in Paris: A stunning example of French Gothic architecture, Notre-Dame Cathedral is known for its intricate façade and beautiful stained glass windows.
#
# 6. Palace of the Popes in Avignon: This grand palace was the residence of the popes in the 14th century and is now a UNESCO World Heritage Site.
#
# 7. Château de Chambord in the Loire Valley: A magnificent Renaissance château known for its distinctive French architecture and sprawling grounds.
#
# These are just a few of the many famous landmarks in France that attract visitors from around the world.
# --------------------------------------------------
# User: How is the cuisine different from other countries?
# Assistant: French cuisine is known for its focus on high-quality ingredients and meticulous preparation techniques. It often features rich sauces, flavorful herbs and seasonings, and a wide variety of meats, cheeses, and pastries. French cuisine also places a strong emphasis on presentation and aesthetics. French cooking techniques, such as sautéing, braising, and baking, have influenced many other culinary traditions around the world. Additionally, the French take great pride in their culinary heritage and the dining experience, with meals often being enjoyed leisurely and viewed as a social activity.
# --------------------------------------------------
# User: What is the best time of year to visit?
# Assistant: The best time to visit France largely depends on your preferences and what you would like to experience during your trip.
#
# Spring (from March to May) and Fall (from September to October) are generally considered the best times to visit. The weather during these seasons is mild, and popular tourist destinations are less crowded compared to the peak summer months.
#
# Summer (from June to August) is the peak tourist season in France, with warm weather and longer daylight hours ideal for outdoor activities. However, this is when many attractions can be crowded, and prices for accommodations and flights tend to be higher.
#
# Winter (from December to February) can be a magical time to visit, especially in regions like the French Alps for skiing and snow sports. Cities like Paris also have their charm during the festive season, with Christmas markets and decorations.
#
# Ultimately, the best time to visit France depends on your personal preferences for weather, activities, and crowd levels.
# --------------------------------------------------

# %%
# Print final conversation for verification
print("\nFinal conversation:")
for message in conversation:
    print(f"{message['role'].capitalize()}: {message['content']}")
# Out:
# Final conversation:
# User: What is the capital of France?
# Assistant: The capital of France is Paris.
# User: How is the cuisine different from other countries?
# Assistant: French cuisine is known for its focus on high-quality ingredients and meticulous preparation techniques. It often features rich sauces, flavorful herbs and seasonings, and a wide variety of meats, cheeses, and pastries. French cuisine also places a strong emphasis on presentation and aesthetics. French cooking techniques, such as sautéing, braising, and baking, have influenced many other culinary traditions around the world. Additionally, the French take great pride in their culinary heritage and the dining experience, with meals often being enjoyed leisurely and viewed as a social activity.
# User: What is the best time of year to visit?
# Assistant: The best time to visit France largely depends on your preferences and what you would like to experience during your trip.
#
# Spring (from March to May) and Fall (from September to October) are generally considered the best times to visit. The weather during these seasons is mild, and popular tourist destinations are less crowded compared to the peak summer months.
#
# Summer (from June to August) is the peak tourist season in France, with warm weather and longer daylight hours ideal for outdoor activities. However, this is when many attractions can be crowded, and prices for accommodations and flights tend to be higher.
#
# Winter (from December to February) can be a magical time to visit, especially in regions like the French Alps for skiing and snow sports. Cities like Paris also have their charm during the festive season, with Christmas markets and decorations.
#
# Ultimately, the best time to visit France depends on your personal preferences for weather, activities, and crowd levels.

# %% [markdown]
# ## Other NLP applications with the LLM
# -------------------------------------

# %% [markdown]
# #### Language Translation
# The OpenAI API also supports language translation.
#
# You can provide a piece of text in one language and ask the API to translate it into another language. Here’s an example:

# %%
system
# Out:
# []

# %%
completion = client.chat.completions.create (
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": "You are a poetic assistant, skilled in explaining complex programming concepts with creative flair."},
    {"role": "user",   "content": "Compose a poem that explains the \
                                   concept of recursion in programming, \
                                   in max 50 words"}
  ]
)

# %%
# text = "Hello, how are you?"

# response = openai.Completion.create(
#   engine = "text-davinci-003",
#   prompt = f"Translate from English to Hindi: {text}",
#   max_tokens=50
# )

# translation = response.choices[0].text.strip()
# print(translation)

# %% [markdown]
# #### Sentiment Analysis
# You can also use the OpenAI API for sentiment analysis. Given a piece of text, the API will tell you whether it has a positive or negative sentiment. Here’s an example:

# %%
text = "I love horror movies!"

response = client.chat.completions.create(
                  model="gpt-3.5-turbo",
                  messages=[
                    {"role": "system", "content": "You are a NLP expert"},
                    {"role": "user",   "content": f"Perform sentiment analysis of given text : {text}"
                    
                    }
                  ]
)

sentiment = response.choices[0].message.content.replace("\n", " ")
print(sentiment)
# Out:
# The given text "I love horror movies!" has a positive sentiment. The word "love" indicates a strong positive emotion towards horror movies.   In sentiment analysis, the overall sentiment of a text is determined by analyzing the words and phrases used in the text to understand the underlying sentiment, which can be positive, negative, or neutral. In this case, the sentiment is positive as the individual expresses their love for horror movies.

# %% [markdown]
# #### Question-Answering
# The OpenAI API also supports question-answering. You can provide a context and a question, and the API will return an answer based on that context. Here’s an example:

# %%
context  = "Albert Einstein was a German-born theoretical physicist who developed the \
theory of relativity."

question = "Where was Albert Einstein born?"

response = client.chat.completions.create(
                  model="gpt-3.5-turbo",
                  messages=[
                    {"role": "system", "content": "You are a NLP expert"},
                    {"role": "user",   "content": f"Question answering:\nContext: {context}\nQuestion: {question}"
                    
                    }
                  ],
                 temperature= 0.001
)

answer = response.choices[0].message.content.replace("\n", " ")
print(answer)
# Out:
# Albert Einstein was born in Ulm, in the Kingdom of Württemberg in the German Empire on March 14, 1879.

# %%
context = '''positive for TTF 1, and napsin A, 
suggestive of lung adenocarcinoma. Molecular testing was performed, that did not reveal actionable
therapeutically targetable mutations. She underwent chemotherapy therapy, 
to this paraspinal mass, administered concurrently with carboplatin and paclitaxel. 
She was then treated with 4 cycles of systemic therapy with carboplatin, and pemetrexed, and then.'''

question = '''

Did the patient undergo radiation therapy or any similar therapies in recent past or in the past? 

Your answer should be either 'Yes' or 'NO' or "Not sure' ONLY, With a label prefix "Answer",
Followed by reasoning in 50 words with a label prefix "Explanation",
followed by confidence score & scale, with a label prefix "Confidence Score/ label : "

'''

response = client.chat.completions.create(
                  model="gpt-4o",
                  messages=[
                    {"role": "system", "content": "You are a NLP expert"},
                    {"role": "user",   "content": f"Question answering:\nContext: {context}\nQuestion: {question}",
                    
                    }
                  ],
                 temperature= 0.001
)

answer = response.choices[0].message.content.replace("\n", " ")
print(answer)
# Out:
# Answer: Not sure  Explanation: The context mentions chemotherapy with carboplatin and paclitaxel, but it does not explicitly state whether radiation therapy or similar therapies were administered. Without specific mention of radiation therapy, it is unclear if the patient underwent such treatment.  Confidence Score/label: 60% / Low
